# %% [markdown]
# ## PROJECT DESCRIPTION

# %% [markdown]
# Sales analytics is the practice of generating insights from sales data, trends, and metrics to set targets and forecast future sales performance.
#
# In this analytics project,  I explore the data to evaluate the performance of the sales team against specified goals.
# The project provides insights about the top performing and underperforming products/services, the problems in selling and market opportunities, sales forecasting, and sales activities that generate revenue.

# %% [markdown]
# ### PROJECT QUESTIONS AND ANALYSIS
#
# In the analysis of the project data, these questions will be answered with accompanying visualizations.
#
# 1: What was the best Year for sales? How much was earned that Year?
#
# 2: What City had the highest number of sales?
#
# 3: What was the best month for sales? How much was earned that month?
#
# 4: What products are most often sold together?
#
# 5: What product sold the most? Why do you think it sold the most?
#
# 6: What time should we display adverstisement to maximize likelihood of customer's buying product?
#
# 7: What is the probability that people will order USB-C Charging Cable?
#
# 8: What is the probability that people will orderiPhone?
#
# 9: What is the probability that people will order Google Phone?
#
# 10:What is the probability that people will order Wired Headphones?

# %% [markdown]
# ### IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# ### IMPORT DATASETS

# %%
jan_data = pd.read_csv("Sales_January_2019.csv")
feb_data = pd.read_csv("Sales_February_2019.csv")
mar_data = pd.read_csv("Sales_March_2019.csv")
apr_data = pd.read_csv("Sales_April_2019.csv")
may_data = pd.read_csv("Sales_May_2019.csv")
jun_data = pd.read_csv("Sales_June_2019.csv")
jul_data = pd.read_csv("Sales_July_2019.csv")
aug_data = pd.read_csv("Sales_August_2019.csv")
sep_data = pd.read_csv("Sales_September_2019.csv")
oct_data = pd.read_csv("Sales_October_2019.csv")
nov_data = pd.read_csv("Sales_November_2019.csv")
dec_data = pd.read_csv("Sales_December_2019.csv")

# %% [markdown]
# ## Analyze details of each of the datasets

# %% [markdown]
# ### January product sales

# %%
# Checking the head of data

jan_data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
# Checking the shape of the data

jan_data.shape
# Out:
# (9723, 6)

# %% [markdown]
# There are 9671 rows and 6 columns in the dataset

# %%
# Checking basic info of data

jan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9723 entries, 0 to 9722
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          9697 non-null   object
#  1   Product           9697 non-null   object
#  2   Quantity Ordered  9697 non-null   object
#  3   Price Each        9697 non-null   object
#  4   Order Date        9697 non-null   object
#  5   Purchase Address  9697 non-null   object
# dtypes: object(6)
# memory usage: 455.9+ KB

# %%
# Checking for null values

jan_data.isna().sum()
# Out:
# Order ID            26
# Product             26
# Quantity Ordered    26
# Price Each          26
# Order Date          26
# Purchase Address    26
# dtype: int64

# %% [markdown]
# There are 26 instances of NaN values in the dataset. These entries will be dropped.

# %%
# Drop NaN values

jan_data.dropna(how="all", axis=0, inplace=True)

# %% [markdown]
# #### Checking for duplicated entries

# %%
jan_data.duplicated().any()
# Out:
# True

# %%
# Checking the number of duplicates

jan_data.duplicated().sum()
# Out:
# 25

# %%
# Investigating the occurrence of duplicates

jan_data[jan_data.duplicated()]
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 875     142071     AA Batteries (4-pack)                 1        3.84
# 1102  Order ID                   Product  Quantity Ordered  Price Each
# 1194  Order ID                   Product  Quantity Ordered  Price Each
# 1897  Order ID                   Product  Quantity Ordered  Price Each
# 2463  Order ID                   Product  Quantity Ordered  Price Each
# 3115  Order ID                   Product  Quantity Ordered  Price Each
# 3247  Order ID                   Product  Quantity Ordered  Price Each
# 3612  Order ID                   Product  Quantity Ordered  Price Each
# 3623  Order ID                   Product  Quantity Ordered  Price Each
# 4126    145143  Lightning Charging Cable                 1       14.95
# 4901  Order ID                   Product  Quantity Ordered  Price Each
# 5593  Order ID                   Product  Quantity Ordered  Price Each
# 5811    146765              Google Phone                 1         600
# 6506  Order ID                   Product  Quantity Ordered  Price Each
# 6807    147707          Wired Headphones                 1       11.99
# 7544  Order ID                   Product  Quantity Ordered  Price Each
# 7674  Order ID                   Product  Quantity Ordered  Price Each
# 8134    148984      USB-C Charging Cable                 1       11.95
# 8271  Order ID                   Product  Quantity Ordered  Price Each
# 8309    149149  Lightning Charging Cable                 1       14.95
# 8470    149308  Apple Airpods Headphones                 1         150
# 8690    149515      USB-C Charging Cable                 1       11.95
# 8923    149738      USB-C Charging Cable                 1       11.95
# 9311  Order ID                   Product  Quantity Ordered  Price Each
# 9427    150216          Wired Headphones                 1       11.99
#
#           Order Date                           Purchase Address
# 875   01/17/19 23:02               131 2nd St, Boston, MA 02215
# 1102      Order Date                           Purchase Address
# 1194      Order Date                           Purchase Address
# 1897      Order Date                           Purchase Address
# 2463      Order Date                           Purchase Address
# 3115      Order Date                           Purchase Address
# 3247      Order Date                           Purchase Address
# 3612      Order Date                           Purchase Address
# 3623      Order Date                           Purchase Address
# 4126  01/06/19 03:01  182 Jefferson St, San Francisco, CA 94016
# 4901      Order Date                           Purchase Address
# 5593      Order Date                           Purchase Address
# 5811  01/21/19 11:23   918 Highland St, New York City, NY 10001
# 6506      Order Date                           Purchase Address
# 6807  01/04/19 16:50               883 4th St, Dallas, TX 75001
# 7544      Order Date                           Purchase Address
# 7674      Order Date                           Purchase Address
# 8134  01/08/19 17:36              562 14th St, Boston, MA 02215
# 8271      Order Date                           Purchase Address
# 8309  01/12/19 12:30               180 1st St, Boston, MA 02215
# 8470  01/02/19 23:07    351 Madison St, New York City, NY 10001
# 8690  01/14/19 21:19         913 10th St, Los Angeles, CA 90001
# 8923  01/11/19 11:22       612 West St, New York City, NY 10001
# 9311      Order Date                           Purchase Address
# 9427  01/21/19 09:20       691 Pine St, San Francisco, CA 94016

# %% [markdown]
# There are instances where "Order ID" column has non-numeric values. Drop these rows from the dataset.

# %%
# Drop rows that have Order ID as values in the "Order ID" column

jan_data = jan_data[jan_data["Order ID"] != "Order ID"]

# %%
jan_data[jan_data.duplicated()]
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 875    142071     AA Batteries (4-pack)                1       3.84
# 4126   145143  Lightning Charging Cable                1      14.95
# 5811   146765              Google Phone                1        600
# 6807   147707          Wired Headphones                1      11.99
# 8134   148984      USB-C Charging Cable                1      11.95
# 8309   149149  Lightning Charging Cable                1      14.95
# 8470   149308  Apple Airpods Headphones                1        150
# 8690   149515      USB-C Charging Cable                1      11.95
# 8923   149738      USB-C Charging Cable                1      11.95
# 9427   150216          Wired Headphones                1      11.99
#
#           Order Date                           Purchase Address
# 875   01/17/19 23:02               131 2nd St, Boston, MA 02215
# 4126  01/06/19 03:01  182 Jefferson St, San Francisco, CA 94016
# 5811  01/21/19 11:23   918 Highland St, New York City, NY 10001
# 6807  01/04/19 16:50               883 4th St, Dallas, TX 75001
# 8134  01/08/19 17:36              562 14th St, Boston, MA 02215
# 8309  01/12/19 12:30               180 1st St, Boston, MA 02215
# 8470  01/02/19 23:07    351 Madison St, New York City, NY 10001
# 8690  01/14/19 21:19         913 10th St, Los Angeles, CA 90001
# 8923  01/11/19 11:22       612 West St, New York City, NY 10001
# 9427  01/21/19 09:20       691 Pine St, San Francisco, CA 94016

# %% [markdown]
# #### Investigate the issue of duplicates

# %%
# Order ID --- 142071

jan_data[jan_data["Order ID"] == "142071"]
# Out:
#     Order ID                Product Quantity Ordered Price Each  \
# 874   142071  AA Batteries (4-pack)                1       3.84
# 875   142071  AA Batteries (4-pack)                1       3.84
#
#          Order Date              Purchase Address
# 874  01/17/19 23:02  131 2nd St, Boston, MA 02215
# 875  01/17/19 23:02  131 2nd St, Boston, MA 02215

# %%
# Order ID --- 145143

jan_data[jan_data["Order ID"] == "145143"]
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 4125   145143  Lightning Charging Cable                1      14.95
# 4126   145143  Lightning Charging Cable                1      14.95
#
#           Order Date                           Purchase Address
# 4125  01/06/19 03:01  182 Jefferson St, San Francisco, CA 94016
# 4126  01/06/19 03:01  182 Jefferson St, San Francisco, CA 94016

# %%
# Order ID --- 146765

jan_data[jan_data["Order ID"] == "146765"]
# Out:
#      Order ID       Product Quantity Ordered Price Each      Order Date  \
# 5810   146765  Google Phone                1        600  01/21/19 11:23
# 5811   146765  Google Phone                1        600  01/21/19 11:23
#
#                               Purchase Address
# 5810  918 Highland St, New York City, NY 10001
# 5811  918 Highland St, New York City, NY 10001

# %%
# Order ID --- 147707

jan_data[jan_data["Order ID"] == "147707"]
# Out:
#      Order ID           Product Quantity Ordered Price Each      Order Date  \
# 6806   147707  Wired Headphones                1      11.99  01/04/19 16:50
# 6807   147707  Wired Headphones                1      11.99  01/04/19 16:50
#
#                   Purchase Address
# 6806  883 4th St, Dallas, TX 75001
# 6807  883 4th St, Dallas, TX 75001

# %%
# Order ID --- 148984

jan_data[jan_data["Order ID"] == "148984"]
# Out:
#      Order ID               Product Quantity Ordered Price Each  \
# 8133   148984  USB-C Charging Cable                1      11.95
# 8134   148984  USB-C Charging Cable                1      11.95
#
#           Order Date               Purchase Address
# 8133  01/08/19 17:36  562 14th St, Boston, MA 02215
# 8134  01/08/19 17:36  562 14th St, Boston, MA 02215

# %%
# Order ID --- 149149

jan_data[jan_data["Order ID"] == "149149"]
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 8308   149149  Lightning Charging Cable                1      14.95
# 8309   149149  Lightning Charging Cable                1      14.95
#
#           Order Date              Purchase Address
# 8308  01/12/19 12:30  180 1st St, Boston, MA 02215
# 8309  01/12/19 12:30  180 1st St, Boston, MA 02215

# %%
# Order ID --- 149308

jan_data[jan_data["Order ID"] == "149308"]
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 8469   149308  Apple Airpods Headphones                1        150
# 8470   149308  Apple Airpods Headphones                1        150
#
#           Order Date                         Purchase Address
# 8469  01/02/19 23:07  351 Madison St, New York City, NY 10001
# 8470  01/02/19 23:07  351 Madison St, New York City, NY 10001

# %%
# Order ID --- 149515

jan_data[jan_data["Order ID"] == "149515"]
# Out:
#      Order ID               Product Quantity Ordered Price Each  \
# 8689   149515  USB-C Charging Cable                1      11.95
# 8690   149515  USB-C Charging Cable                1      11.95
#
#           Order Date                    Purchase Address
# 8689  01/14/19 21:19  913 10th St, Los Angeles, CA 90001
# 8690  01/14/19 21:19  913 10th St, Los Angeles, CA 90001

# %%
# Order ID --- 149738

jan_data[jan_data["Order ID"] == "149738"]
# Out:
#      Order ID               Product Quantity Ordered Price Each  \
# 8922   149738  USB-C Charging Cable                1      11.95
# 8923   149738  USB-C Charging Cable                1      11.95
#
#           Order Date                      Purchase Address
# 8922  01/11/19 11:22  612 West St, New York City, NY 10001
# 8923  01/11/19 11:22  612 West St, New York City, NY 10001

# %%
# Order ID --- 150216

jan_data[jan_data["Order ID"] == "150216"]
# Out:
#      Order ID           Product Quantity Ordered Price Each      Order Date  \
# 9426   150216  Wired Headphones                1      11.99  01/21/19 09:20
# 9427   150216  Wired Headphones                1      11.99  01/21/19 09:20
#
#                           Purchase Address
# 9426  691 Pine St, San Francisco, CA 94016
# 9427  691 Pine St, San Francisco, CA 94016

# %% [markdown]
# From the duplicates investigations, it can be realised that each duplicated entries had same values. One instance of each duplicated entry will be dropped.

# %%
# Drop duplicated entries

jan_data.drop_duplicates(subset=None, keep="first", inplace=True)

# %% [markdown]
# ### February product sales

# %%
# Checking the head of the data

feb_data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   150502                    iPhone                1        700
# 1   150503     AA Batteries (4-pack)                1       3.84
# 2   150504    27in 4K Gaming Monitor                1     389.99
# 3   150505  Lightning Charging Cable                1      14.95
# 4   150506     AA Batteries (4-pack)                2       3.84
#
#        Order Date                     Purchase Address
# 0  02/18/19 01:35    866 Spruce St, Portland, ME 04101
# 1  02/13/19 07:24  18 13th St, San Francisco, CA 94016
# 2  02/18/19 09:46   52 6th St, New York City, NY 10001
# 3  02/02/19 16:47     129 Cherry St, Atlanta, GA 30301
# 4  02/28/19 20:32    548 Lincoln St, Seattle, WA 98101

# %%
# Checking the shape of the data

feb_data.shape
# Out:
# (12036, 6)

# %% [markdown]
# There are 12036 rows and 6 columns in the data

# %%
# Checking the basic info of the data

feb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12036 entries, 0 to 12035
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          12004 non-null  object
#  1   Product           12004 non-null  object
#  2   Quantity Ordered  12004 non-null  object
#  3   Price Each        12004 non-null  object
#  4   Order Date        12004 non-null  object
#  5   Purchase Address  12004 non-null  object
# dtypes: object(6)
# memory usage: 564.3+ KB

# %%
# Checking for the null values in the data

feb_data.isna().sum()
# Out:
# Order ID            32
# Product             32
# Quantity Ordered    32
# Price Each          32
# Order Date          32
# Purchase Address    32
# dtype: int64

# %% [markdown]
# There are 32 instances of NaN values in the data

# %%
# Drop NaN values from the data

feb_data.dropna(how="all", axis=0, inplace=True)

# %%
# Checking for duplicates in the data

feb_data.duplicated().any()
# Out:
# True

# %%
# Checking the number of duplicates

feb_data.duplicated().sum()
# Out:
# 35

# %% [markdown]
# There are 35 instances of duplicated entries in the data

# %%
# Investigating the occurrence of duplicates

feb_data[feb_data.duplicated()]
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 432      150917    Lightning Charging Cable                 1       14.95
# 442      150925                      iPhone                 1         700
# 461      150943        USB-C Charging Cable                 1       11.95
# 548      151024            Wired Headphones                 1       11.99
# 1164     151616        USB-C Charging Cable                 1       11.95
# 1224     151673            Wired Headphones                 1       11.99
# 1417     151856        USB-C Charging Cable                 1       11.95
# 1904   Order ID                     Product  Quantity Ordered  Price Each
# 1918     152330  Bose SoundSport Headphones                 1       99.99
# 2050   Order ID                     Product  Quantity Ordered  Price Each
# 2225   Order ID                     Product  Quantity Ordered  Price Each
# 2937     153304            Wired Headphones                 1       11.99
# 2949     153315            Wired Headphones                 1       11.99
# 3091   Order ID                     Product  Quantity Ordered  Price Each
# 3128   Order ID                     Product  Quantity Ordered  Price Each
# 3142   Order ID                     Product  Quantity Ordered  Price Each
# 3360   Order ID                     Product  Quantity Ordered  Price Each
# 3426   Order ID                     Product  Quantity Ordered  Price Each
# 3831   Order ID                     Product  Quantity Ordered  Price Each
# 4013   Order ID                     Product  Quantity Ordered  Price Each
# 4070   Order ID                     Product  Quantity Ordered  Price Each
# 4446     154737    Lightning Charging Cable                 1       14.95
# 4457     154747      27in 4K Gaming Monitor                 1      389.99
# 4518   Order ID                     Product  Quantity Ordered  Price Each
# 5315   Order ID                     Product  Quantity Ordered  Price Each
# 5450     155697       AA Batteries (4-pack)                 1        3.84
# 5880     156109  Bose SoundSport Headphones                 1       99.99
# 6025     156247      AAA Batteries (4-pack)                 1        2.99
# 6099   Order ID                     Product  Quantity Ordered  Price Each
# 6957   Order ID                     Product  Quantity Ordered  Price Each
# 7301   Order ID                     Product  Quantity Ordered  Price Each
# 8111     158236       AA Batteries (4-pack)                 1        3.84
# 8734     158841      34in Ultrawide Monitor                 1      379.99
# 11528  Order ID                     Product  Quantity Ordered  Price Each
# 11574    161567    Apple Airpods Headphones                 1         150
#
#            Order Date                         Purchase Address
# 432    02/06/19 16:07            111 10th St, Austin, TX 73301
# 442    02/07/19 17:43             784 Elm St, Boston, MA 02215
# 461    02/06/19 19:13             759 1st St, Austin, TX 73301
# 548    02/19/19 08:39           35 Pine St, Portland, OR 97035
# 1164   02/25/19 19:29          666 Meadow St, Boston, MA 02215
# 1224   02/10/19 21:52          504 Center St, Dallas, TX 75001
# 1417   02/06/19 12:11  475 Jackson St, San Francisco, CA 94016
# 1904       Order Date                         Purchase Address
# 1918   02/25/19 18:53    827 Dogwood St, Los Angeles, CA 90001
# 2050       Order Date                         Purchase Address
# 2225       Order Date                         Purchase Address
# 2937   02/12/19 20:08           74 Meadow St, Austin, TX 73301
# 2949   02/13/19 14:47      953 Jefferson St, Atlanta, GA 30301
# 3091       Order Date                         Purchase Address
# 3128       Order Date                         Purchase Address
# 3142       Order Date                         Purchase Address
# 3360       Order Date                         Purchase Address
# 3426       Order Date                         Purchase Address
# 3831       Order Date                         Purchase Address
# 4013       Order Date                         Purchase Address
# 4070       Order Date                         Purchase Address
# 4446   02/01/19 17:59     513 10th St, San Francisco, CA 94016
# 4457   02/01/19 22:46           367 Cedar St, Austin, TX 73301
# 4518       Order Date                         Purchase Address
# 5315       Order Date                         Purchase Address
# 5450   02/13/19 15:17          961 Spruce St, Boston, MA 02215
# 5880   02/18/19 09:18         450 Jackson St, Boston, MA 02215
# 6025   02/09/19 07:29    511 Dogwood St, Los Angeles, CA 90001
# 6099       Order Date                         Purchase Address
# 6957       Order Date                         Purchase Address
# 7301       Order Date                         Purchase Address
# 8111   02/19/19 09:49     319 West St, San Francisco, CA 94016
# 8734   02/01/19 23:16          786 Willow St, Boston, MA 02215
# 11528      Order Date                         Purchase Address
# 11574  02/10/19 11:42   413 Walnut St, San Francisco, CA 94016

# %% [markdown]
# There are instances where "Order ID" column has non-numeric values. Drop these rows from the dataset.

# %%
# Drop rows that have Order ID as values in the "Order ID" column

feb_data = feb_data[feb_data["Order ID"] != "Order ID"]

# %%
feb_data[feb_data.duplicated()]
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 432     150917    Lightning Charging Cable                1      14.95
# 442     150925                      iPhone                1        700
# 461     150943        USB-C Charging Cable                1      11.95
# 548     151024            Wired Headphones                1      11.99
# 1164    151616        USB-C Charging Cable                1      11.95
# 1224    151673            Wired Headphones                1      11.99
# 1417    151856        USB-C Charging Cable                1      11.95
# 1918    152330  Bose SoundSport Headphones                1      99.99
# 2937    153304            Wired Headphones                1      11.99
# 2949    153315            Wired Headphones                1      11.99
# 4446    154737    Lightning Charging Cable                1      14.95
# 4457    154747      27in 4K Gaming Monitor                1     389.99
# 5450    155697       AA Batteries (4-pack)                1       3.84
# 5880    156109  Bose SoundSport Headphones                1      99.99
# 6025    156247      AAA Batteries (4-pack)                1       2.99
# 8111    158236       AA Batteries (4-pack)                1       3.84
# 8734    158841      34in Ultrawide Monitor                1     379.99
# 11574   161567    Apple Airpods Headphones                1        150
#
#            Order Date                         Purchase Address
# 432    02/06/19 16:07            111 10th St, Austin, TX 73301
# 442    02/07/19 17:43             784 Elm St, Boston, MA 02215
# 461    02/06/19 19:13             759 1st St, Austin, TX 73301
# 548    02/19/19 08:39           35 Pine St, Portland, OR 97035
# 1164   02/25/19 19:29          666 Meadow St, Boston, MA 02215
# 1224   02/10/19 21:52          504 Center St, Dallas, TX 75001
# 1417   02/06/19 12:11  475 Jackson St, San Francisco, CA 94016
# 1918   02/25/19 18:53    827 Dogwood St, Los Angeles, CA 90001
# 2937   02/12/19 20:08           74 Meadow St, Austin, TX 73301
# 2949   02/13/19 14:47      953 Jefferson St, Atlanta, GA 30301
# 4446   02/01/19 17:59     513 10th St, San Francisco, CA 94016
# 4457   02/01/19 22:46           367 Cedar St, Austin, TX 73301
# 5450   02/13/19 15:17          961 Spruce St, Boston, MA 02215
# 5880   02/18/19 09:18         450 Jackson St, Boston, MA 02215
# 6025   02/09/19 07:29    511 Dogwood St, Los Angeles, CA 90001
# 8111   02/19/19 09:49     319 West St, San Francisco, CA 94016
# 8734   02/01/19 23:16          786 Willow St, Boston, MA 02215
# 11574  02/10/19 11:42   413 Walnut St, San Francisco, CA 94016

# %% [markdown]
# #### Investigating the issue of duplicated entries

# %%
# Order ID --- 150917

feb_data[feb_data["Order ID"] == "150917"]
# Out:
#     Order ID                   Product Quantity Ordered Price Each  \
# 431   150917  Lightning Charging Cable                1      14.95
# 432   150917  Lightning Charging Cable                1      14.95
#
#          Order Date               Purchase Address
# 431  02/06/19 16:07  111 10th St, Austin, TX 73301
# 432  02/06/19 16:07  111 10th St, Austin, TX 73301

# %%
# Order ID --- 150925

feb_data[feb_data["Order ID"] == "150925"]
# Out:
#     Order ID                   Product Quantity Ordered Price Each  \
# 440   150925                    iPhone                1        700
# 441   150925  Lightning Charging Cable                1      14.95
# 442   150925                    iPhone                1        700
#
#          Order Date              Purchase Address
# 440  02/07/19 17:43  784 Elm St, Boston, MA 02215
# 441  02/07/19 17:43  784 Elm St, Boston, MA 02215
# 442  02/07/19 17:43  784 Elm St, Boston, MA 02215

# %%
# Order ID --- 150943

feb_data[feb_data["Order ID"] == "150943"]
# Out:
#     Order ID               Product Quantity Ordered Price Each  \
# 460   150943  USB-C Charging Cable                1      11.95
# 461   150943  USB-C Charging Cable                1      11.95
#
#          Order Date              Purchase Address
# 460  02/06/19 19:13  759 1st St, Austin, TX 73301
# 461  02/06/19 19:13  759 1st St, Austin, TX 73301

# %%
# Order ID --- 151024

feb_data[feb_data["Order ID"] == "151024"]
# Out:
#     Order ID           Product Quantity Ordered Price Each      Order Date  \
# 547   151024  Wired Headphones                1      11.99  02/19/19 08:39
# 548   151024  Wired Headphones                1      11.99  02/19/19 08:39
#
#                    Purchase Address
# 547  35 Pine St, Portland, OR 97035
# 548  35 Pine St, Portland, OR 97035

# %%
# Order ID --- 151616

feb_data[feb_data["Order ID"] == "151616"]
# Out:
#      Order ID               Product Quantity Ordered Price Each  \
# 1163   151616  USB-C Charging Cable                1      11.95
# 1164   151616  USB-C Charging Cable                1      11.95
#
#           Order Date                 Purchase Address
# 1163  02/25/19 19:29  666 Meadow St, Boston, MA 02215
# 1164  02/25/19 19:29  666 Meadow St, Boston, MA 02215

# %%
# Order ID --- 151673

feb_data[feb_data["Order ID"] == "151673"]
# Out:
#      Order ID           Product Quantity Ordered Price Each      Order Date  \
# 1223   151673  Wired Headphones                1      11.99  02/10/19 21:52
# 1224   151673  Wired Headphones                1      11.99  02/10/19 21:52
#
#                      Purchase Address
# 1223  504 Center St, Dallas, TX 75001
# 1224  504 Center St, Dallas, TX 75001

# %%
# Order ID --- 151856

feb_data[feb_data["Order ID"] == "151856"]
# Out:
#      Order ID               Product Quantity Ordered Price Each  \
# 1416   151856  USB-C Charging Cable                1      11.95
# 1417   151856  USB-C Charging Cable                1      11.95
#
#           Order Date                         Purchase Address
# 1416  02/06/19 12:11  475 Jackson St, San Francisco, CA 94016
# 1417  02/06/19 12:11  475 Jackson St, San Francisco, CA 94016

# %%
# Order ID --- 152330

feb_data[feb_data["Order ID"] == "152330"]
# Out:
#      Order ID                     Product Quantity Ordered Price Each  \
# 1917   152330  Bose SoundSport Headphones                1      99.99
# 1918   152330  Bose SoundSport Headphones                1      99.99
#
#           Order Date                       Purchase Address
# 1917  02/25/19 18:53  827 Dogwood St, Los Angeles, CA 90001
# 1918  02/25/19 18:53  827 Dogwood St, Los Angeles, CA 90001

# %%
# Order ID --- 153304

feb_data[feb_data["Order ID"] == "153304"]
# Out:
#      Order ID           Product Quantity Ordered Price Each      Order Date  \
# 2936   153304  Wired Headphones                1      11.99  02/12/19 20:08
# 2937   153304  Wired Headphones                1      11.99  02/12/19 20:08
#
#                     Purchase Address
# 2936  74 Meadow St, Austin, TX 73301
# 2937  74 Meadow St, Austin, TX 73301

# %%
# Order ID --- 153315

feb_data[feb_data["Order ID"] == "153315"]
# Out:
#      Order ID           Product Quantity Ordered Price Each      Order Date  \
# 2948   153315  Wired Headphones                1      11.99  02/13/19 14:47
# 2949   153315  Wired Headphones                1      11.99  02/13/19 14:47
#
#                          Purchase Address
# 2948  953 Jefferson St, Atlanta, GA 30301
# 2949  953 Jefferson St, Atlanta, GA 30301

# %%
# Order ID --- 154747

feb_data[feb_data["Order ID"] == "154747"]
# Out:
#      Order ID                 Product Quantity Ordered Price Each  \
# 4456   154747  27in 4K Gaming Monitor                1     389.99
# 4457   154747  27in 4K Gaming Monitor                1     389.99
#
#           Order Date                Purchase Address
# 4456  02/01/19 22:46  367 Cedar St, Austin, TX 73301
# 4457  02/01/19 22:46  367 Cedar St, Austin, TX 73301

# %%
# Order ID --- 155697

feb_data[feb_data["Order ID"] == "155697"]
# Out:
#      Order ID                Product Quantity Ordered Price Each  \
# 5449   155697  AA Batteries (4-pack)                1       3.84
# 5450   155697  AA Batteries (4-pack)                1       3.84
#
#           Order Date                 Purchase Address
# 5449  02/13/19 15:17  961 Spruce St, Boston, MA 02215
# 5450  02/13/19 15:17  961 Spruce St, Boston, MA 02215

# %%
# Order ID --- 156109

feb_data[feb_data["Order ID"] == "156109"]
# Out:
#      Order ID                     Product Quantity Ordered Price Each  \
# 5879   156109  Bose SoundSport Headphones                1      99.99
# 5880   156109  Bose SoundSport Headphones                1      99.99
#
#           Order Date                  Purchase Address
# 5879  02/18/19 09:18  450 Jackson St, Boston, MA 02215
# 5880  02/18/19 09:18  450 Jackson St, Boston, MA 02215

# %%
# Order ID --- 156247

feb_data[feb_data["Order ID"] == "156247"]
# Out:
#      Order ID                 Product Quantity Ordered Price Each  \
# 6024   156247  AAA Batteries (4-pack)                1       2.99
# 6025   156247  AAA Batteries (4-pack)                1       2.99
#
#           Order Date                       Purchase Address
# 6024  02/09/19 07:29  511 Dogwood St, Los Angeles, CA 90001
# 6025  02/09/19 07:29  511 Dogwood St, Los Angeles, CA 90001

# %%
# Order ID --- 158236

feb_data[feb_data["Order ID"] == "158236"]
# Out:
#      Order ID                Product Quantity Ordered Price Each  \
# 8110   158236  AA Batteries (4-pack)                1       3.84
# 8111   158236  AA Batteries (4-pack)                1       3.84
#
#           Order Date                      Purchase Address
# 8110  02/19/19 09:49  319 West St, San Francisco, CA 94016
# 8111  02/19/19 09:49  319 West St, San Francisco, CA 94016

# %%
# Order ID --- 158841

feb_data[feb_data["Order ID"] == "158841"]
# Out:
#      Order ID                 Product Quantity Ordered Price Each  \
# 8733   158841  34in Ultrawide Monitor                1     379.99
# 8734   158841  34in Ultrawide Monitor                1     379.99
#
#           Order Date                 Purchase Address
# 8733  02/01/19 23:16  786 Willow St, Boston, MA 02215
# 8734  02/01/19 23:16  786 Willow St, Boston, MA 02215

# %%
# Order ID --- 161567

feb_data[feb_data["Order ID"] == "161567"]
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 11573   161567  Apple Airpods Headphones                1        150
# 11574   161567  Apple Airpods Headphones                1        150
#
#            Order Date                        Purchase Address
# 11573  02/10/19 11:42  413 Walnut St, San Francisco, CA 94016
# 11574  02/10/19 11:42  413 Walnut St, San Francisco, CA 94016

# %% [markdown]
# From the duplicates investigations, it can be realised that each duplicated entries had same values. One instance of each duplicated entry will be dropped.

# %%
# Drop duplicated entries

feb_data.drop_duplicates(subset=None, keep="first", inplace=True)

# %% [markdown]
# ### March Product Sales

# %%
# Checking the head of the March Product Sales data

mar_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   162009                      iPhone                1        700
# 1   162009    Lightning Charging Cable                1      14.95
# 2   162009            Wired Headphones                2      11.99
# 3   162010  Bose SoundSport Headphones                1      99.99
# 4   162011      34in Ultrawide Monitor                1     379.99
#
#        Order Date                      Purchase Address
# 0  03/28/19 20:59       942 Church St, Austin, TX 73301
# 1  03/28/19 20:59       942 Church St, Austin, TX 73301
# 2  03/28/19 20:59       942 Church St, Austin, TX 73301
# 3  03/17/19 05:39  261 10th St, San Francisco, CA 94016
# 4  03/10/19 00:01  764 13th St, San Francisco, CA 94016

# %%
# Checking the shape of the March sales data

mar_data.shape
# Out:
# (15226, 6)

# %% [markdown]
# From the shape, there are 15226 rows and 6 columns

# %%
# Checking the basic info of the March sales data

mar_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15226 entries, 0 to 15225
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          15189 non-null  object
#  1   Product           15189 non-null  object
#  2   Quantity Ordered  15189 non-null  object
#  3   Price Each        15189 non-null  object
#  4   Order Date        15189 non-null  object
#  5   Purchase Address  15189 non-null  object
# dtypes: object(6)
# memory usage: 713.8+ KB

# %% [markdown]
# From the basic info of the dataset, there are instances of null values. Also, the date is in object format

# %%
# Checking the sum of null values in the data

mar_data.isnull().sum()
# Out:
# Order ID            37
# Product             37
# Quantity Ordered    37
# Price Each          37
# Order Date          37
# Purchase Address    37
# dtype: int64

# %% [markdown]
# There are 37 instances of null values in our dataset. We will drop these values as they seem insignificant as compared to the sum of entries in the entire dataset.

# %%
# Drop null values from the data

mar_data.dropna(how="all", axis=0, inplace=True)

# %%
# Check for duplicates in the dataset

mar_data.duplicated().any()
# Out:
# True

# %%
# Check the sum of duplicated entries

mar_data.duplicated().sum()
# Out:
# 59

# %% [markdown]
# There are 59 instances of duplicated entries in the data

# %%
# Check the instances of the duplicates

mar_data[mar_data.duplicated()]
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 341      162332               Flatscreen TV                 1         300
# 864    Order ID                     Product  Quantity Ordered  Price Each
# 930    Order ID                     Product  Quantity Ordered  Price Each
# 1066     163018      AAA Batteries (4-pack)                 1        2.99
# 1979   Order ID                     Product  Quantity Ordered  Price Each
# 2032   Order ID                     Product  Quantity Ordered  Price Each
# 2107   Order ID                     Product  Quantity Ordered  Price Each
# 2142     164046  Bose SoundSport Headphones                 1       99.99
# 2485   Order ID                     Product  Quantity Ordered  Price Each
# 2728   Order ID                     Product  Quantity Ordered  Price Each
# 2966     164825    Lightning Charging Cable                 1       14.95
# 3338     165180    Lightning Charging Cable                 1       14.95
# 3339   Order ID                     Product  Quantity Ordered  Price Each
# 3651     165481    Apple Airpods Headphones                 1         150
# 3848     165668      34in Ultrawide Monitor                 1      379.99
# 4022   Order ID                     Product  Quantity Ordered  Price Each
# 4050   Order ID                     Product  Quantity Ordered  Price Each
# 4130     165934        USB-C Charging Cable                 1       11.95
# 4223   Order ID                     Product  Quantity Ordered  Price Each
# 4256   Order ID                     Product  Quantity Ordered  Price Each
# 4820   Order ID                     Product  Quantity Ordered  Price Each
# 5215     166981      AAA Batteries (4-pack)                 1        2.99
# 5685     167429    Lightning Charging Cable                 1       14.95
# 5698   Order ID                     Product  Quantity Ordered  Price Each
# 5758   Order ID                     Product  Quantity Ordered  Price Each
# 5923     167654            27in FHD Monitor                 1      149.99
# 6827   Order ID                     Product  Quantity Ordered  Price Each
# 6885   Order ID                     Product  Quantity Ordered  Price Each
# 7033     168724    Apple Airpods Headphones                 1         150
# 7088     168777    Lightning Charging Cable                 1       14.95
# 7203     168888       AA Batteries (4-pack)                 1        3.84
# 7373   Order ID                     Product  Quantity Ordered  Price Each
# 7391   Order ID                     Product  Quantity Ordered  Price Each
# 7655   Order ID                     Product  Quantity Ordered  Price Each
# 7841   Order ID                     Product  Quantity Ordered  Price Each
# 7950     169600            Wired Headphones                 1       11.99
# 8011     169659  Bose SoundSport Headphones                 1       99.99
# 8413   Order ID                     Product  Quantity Ordered  Price Each
# 8487     170109    Apple Airpods Headphones                 1         150
# 8549     170168        USB-C Charging Cable                 1       11.95
# 9549   Order ID                     Product  Quantity Ordered  Price Each
# 9749     171322                20in Monitor                 1      109.99
# 9801     171373       AA Batteries (4-pack)                 2        3.84
# 10041  Order ID                     Product  Quantity Ordered  Price Each
# 10613    172155        USB-C Charging Cable                 1       11.95
# 11039  Order ID                     Product  Quantity Ordered  Price Each
# 11917    173388  Bose SoundSport Headphones                 1       99.99
# 12274  Order ID                     Product  Quantity Ordered  Price Each
# 12305  Order ID                     Product  Quantity Ordered  Price Each
# 12770  Order ID                     Product  Quantity Ordered  Price Each
# 12955  Order ID                     Product  Quantity Ordered  Price Each
# 13283    174691    Apple Airpods Headphones                 1         150
# 13481  Order ID                     Product  Quantity Ordered  Price Each
# 13576    174972        USB-C Charging Cable                 1       11.95
# 13773  Order ID                     Product  Quantity Ordered  Price Each
# 14233  Order ID                     Product  Quantity Ordered  Price Each
# 14416  Order ID                     Product  Quantity Ordered  Price Each
# 14626  Order ID                     Product  Quantity Ordered  Price Each
# 15204    176537    Apple Airpods Headphones                 1         150
#
#            Order Date                         Purchase Address
# 341    03/20/19 14:23           925 10th St, Atlanta, GA 30301
# 864        Order Date                         Purchase Address
# 930        Order Date                         Purchase Address
# 1066   03/17/19 14:10          694 Cedar St, Seattle, WA 98101
# 1979       Order Date                         Purchase Address
# 2032       Order Date                         Purchase Address
# 2107       Order Date                         Purchase Address
# 2142   03/17/19 20:44  837 Dogwood St, San Francisco, CA 94016
# 2485       Order Date                         Purchase Address
# 2728       Order Date                         Purchase Address
# 2966   03/23/19 18:51      34 Pine St, San Francisco, CA 94016
# 3338   03/24/19 12:57            597 5th St, Seattle, WA 98101
# 3339       Order Date                         Purchase Address
# 3651   03/19/19 18:55        422 4th St, Los Angeles, CA 90001
# 3848   03/27/19 11:28  386 Jackson St, San Francisco, CA 94016
# 4022       Order Date                         Purchase Address
# 4050       Order Date                         Purchase Address
# 4130   03/24/19 08:25         521 Forest St, Seattle, WA 98101
# 4223       Order Date                         Purchase Address
# 4256       Order Date                         Purchase Address
# 4820       Order Date                         Purchase Address
# 5215   03/31/19 01:40          557 Wilson St, Dallas, TX 75001
# 5685   03/27/19 05:05     430 Lake St, San Francisco, CA 94016
# 5698       Order Date                         Purchase Address
# 5758       Order Date                         Purchase Address
# 5923   03/29/19 15:10           654 5th St, Portland, OR 97035
# 6827       Order Date                         Purchase Address
# 6885       Order Date                         Purchase Address
# 7033   03/13/19 11:25       552 Park St, Los Angeles, CA 90001
# 7088   03/07/19 14:55     247 Pine St, San Francisco, CA 94016
# 7203   03/18/19 14:26       815 Hill St, Los Angeles, CA 90001
# 7373       Order Date                         Purchase Address
# 7391       Order Date                         Purchase Address
# 7655       Order Date                         Purchase Address
# 7841       Order Date                         Purchase Address
# 7950   03/10/19 11:12    839 Cedar St, New York City, NY 10001
# 8011   03/22/19 16:56         680 Forest St, Seattle, WA 98101
# 8413       Order Date                         Purchase Address
# 8487   03/16/19 13:35         462 Meadow St, Seattle, WA 98101
# 8549   03/09/19 16:58       923 13th St, Los Angeles, CA 90001
# 9549       Order Date                         Purchase Address
# 9749   03/15/19 13:45        357 Meadow St, Portland, ME 04101
# 9801   03/23/19 22:20           49 Sunset St, Austin, TX 73301
# 10041      Order Date                         Purchase Address
# 10613  03/11/19 23:08      712 1st St, New York City, NY 10001
# 11039      Order Date                         Purchase Address
# 11917  03/21/19 15:31    96 Cherry St, San Francisco, CA 94016
# 12274      Order Date                         Purchase Address
# 12305      Order Date                         Purchase Address
# 12770      Order Date                         Purchase Address
# 12955      Order Date                         Purchase Address
# 13283  03/17/19 13:22       672 Highland St, Seattle, WA 98101
# 13481      Order Date                         Purchase Address
# 13576  03/26/19 23:02     389 10th St, New York City, NY 10001
# 13773      Order Date                         Purchase Address
# 14233      Order Date                         Purchase Address
# 14416      Order Date                         Purchase Address
# 14626      Order Date                         Purchase Address
# 15204  03/12/19 07:33           80 Church St, Austin, TX 73301

# %%
# Remove "Order ID" as values in the Order ID column

mar_data = mar_data[mar_data["Order ID"] != "Order ID"]

# %%
# Re-checking the instances of duplicates

mar_data[mar_data.duplicated()]
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 341     162332               Flatscreen TV                1        300
# 1066    163018      AAA Batteries (4-pack)                1       2.99
# 2142    164046  Bose SoundSport Headphones                1      99.99
# 2966    164825    Lightning Charging Cable                1      14.95
# 3338    165180    Lightning Charging Cable                1      14.95
# 3651    165481    Apple Airpods Headphones                1        150
# 3848    165668      34in Ultrawide Monitor                1     379.99
# 4130    165934        USB-C Charging Cable                1      11.95
# 5215    166981      AAA Batteries (4-pack)                1       2.99
# 5685    167429    Lightning Charging Cable                1      14.95
# 5923    167654            27in FHD Monitor                1     149.99
# 7033    168724    Apple Airpods Headphones                1        150
# 7088    168777    Lightning Charging Cable                1      14.95
# 7203    168888       AA Batteries (4-pack)                1       3.84
# 7950    169600            Wired Headphones                1      11.99
# 8011    169659  Bose SoundSport Headphones                1      99.99
# 8487    170109    Apple Airpods Headphones                1        150
# 8549    170168        USB-C Charging Cable                1      11.95
# 9749    171322                20in Monitor                1     109.99
# 9801    171373       AA Batteries (4-pack)                2       3.84
# 10613   172155        USB-C Charging Cable                1      11.95
# 11917   173388  Bose SoundSport Headphones                1      99.99
# 13283   174691    Apple Airpods Headphones                1        150
# 13576   174972        USB-C Charging Cable                1      11.95
# 15204   176537    Apple Airpods Headphones                1        150
#
#            Order Date                         Purchase Address
# 341    03/20/19 14:23           925 10th St, Atlanta, GA 30301
# 1066   03/17/19 14:10          694 Cedar St, Seattle, WA 98101
# 2142   03/17/19 20:44  837 Dogwood St, San Francisco, CA 94016
# 2966   03/23/19 18:51      34 Pine St, San Francisco, CA 94016
# 3338   03/24/19 12:57            597 5th St, Seattle, WA 98101
# 3651   03/19/19 18:55        422 4th St, Los Angeles, CA 90001
# 3848   03/27/19 11:28  386 Jackson St, San Francisco, CA 94016
# 4130   03/24/19 08:25         521 Forest St, Seattle, WA 98101
# 5215   03/31/19 01:40          557 Wilson St, Dallas, TX 75001
# 5685   03/27/19 05:05     430 Lake St, San Francisco, CA 94016
# 5923   03/29/19 15:10           654 5th St, Portland, OR 97035
# 7033   03/13/19 11:25       552 Park St, Los Angeles, CA 90001
# 7088   03/07/19 14:55     247 Pine St, San Francisco, CA 94016
# 7203   03/18/19 14:26       815 Hill St, Los Angeles, CA 90001
# 7950   03/10/19 11:12    839 Cedar St, New York City, NY 10001
# 8011   03/22/19 16:56         680 Forest St, Seattle, WA 98101
# 8487   03/16/19 13:35         462 Meadow St, Seattle, WA 98101
# 8549   03/09/19 16:58       923 13th St, Los Angeles, CA 90001
# 9749   03/15/19 13:45        357 Meadow St, Portland, ME 04101
# 9801   03/23/19 22:20           49 Sunset St, Austin, TX 73301
# 10613  03/11/19 23:08      712 1st St, New York City, NY 10001
# 11917  03/21/19 15:31    96 Cherry St, San Francisco, CA 94016
# 13283  03/17/19 13:22       672 Highland St, Seattle, WA 98101
# 13576  03/26/19 23:02     389 10th St, New York City, NY 10001
# 15204  03/12/19 07:33           80 Church St, Austin, TX 73301

# %% [markdown]
# #### Investigate the issue of duplicated values

# %%
# Order ID --- 162332

mar_data[mar_data["Order ID"] == "162332"]
# Out:
#     Order ID        Product Quantity Ordered Price Each      Order Date  \
# 340   162332  Flatscreen TV                1        300  03/20/19 14:23
# 341   162332  Flatscreen TV                1        300  03/20/19 14:23
#
#                    Purchase Address
# 340  925 10th St, Atlanta, GA 30301
# 341  925 10th St, Atlanta, GA 30301

# %%
# Order ID --- 163018

mar_data[mar_data["Order ID"] == "163018"]
# Out:
#      Order ID                 Product Quantity Ordered Price Each  \
# 1065   163018  AAA Batteries (4-pack)                1       2.99
# 1066   163018  AAA Batteries (4-pack)                1       2.99
#
#           Order Date                 Purchase Address
# 1065  03/17/19 14:10  694 Cedar St, Seattle, WA 98101
# 1066  03/17/19 14:10  694 Cedar St, Seattle, WA 98101

# %%
# Order ID --- 164046

mar_data[mar_data["Order ID"] == "164046"]
# Out:
#      Order ID                     Product Quantity Ordered Price Each  \
# 2141   164046  Bose SoundSport Headphones                1      99.99
# 2142   164046  Bose SoundSport Headphones                1      99.99
#
#           Order Date                         Purchase Address
# 2141  03/17/19 20:44  837 Dogwood St, San Francisco, CA 94016
# 2142  03/17/19 20:44  837 Dogwood St, San Francisco, CA 94016

# %%
# Order ID --- 164825

mar_data[mar_data["Order ID"] == "164825"]
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 2965   164825  Lightning Charging Cable                1      14.95
# 2966   164825  Lightning Charging Cable                1      14.95
#
#           Order Date                     Purchase Address
# 2965  03/23/19 18:51  34 Pine St, San Francisco, CA 94016
# 2966  03/23/19 18:51  34 Pine St, San Francisco, CA 94016

# %%
# Order ID --- 165180

mar_data[mar_data["Order ID"] == "165180"]
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 3337   165180  Lightning Charging Cable                1      14.95
# 3338   165180  Lightning Charging Cable                1      14.95
#
#           Order Date               Purchase Address
# 3337  03/24/19 12:57  597 5th St, Seattle, WA 98101
# 3338  03/24/19 12:57  597 5th St, Seattle, WA 98101

# %%
# Order ID --- 165481

mar_data[mar_data["Order ID"] == "165481"]
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 3650   165481  Apple Airpods Headphones                1        150
# 3651   165481  Apple Airpods Headphones                1        150
#
#           Order Date                   Purchase Address
# 3650  03/19/19 18:55  422 4th St, Los Angeles, CA 90001
# 3651  03/19/19 18:55  422 4th St, Los Angeles, CA 90001

# %%
# Order ID --- 165668

mar_data[mar_data["Order ID"] == "165668"]
# Out:
#      Order ID                 Product Quantity Ordered Price Each  \
# 3847   165668  34in Ultrawide Monitor                1     379.99
# 3848   165668  34in Ultrawide Monitor                1     379.99
#
#           Order Date                         Purchase Address
# 3847  03/27/19 11:28  386 Jackson St, San Francisco, CA 94016
# 3848  03/27/19 11:28  386 Jackson St, San Francisco, CA 94016

# %%
# Order ID --- 165934

mar_data[mar_data["Order ID"] == "165934"]
# Out:
#      Order ID               Product Quantity Ordered Price Each  \
# 4129   165934  USB-C Charging Cable                1      11.95
# 4130   165934  USB-C Charging Cable                1      11.95
#
#           Order Date                  Purchase Address
# 4129  03/24/19 08:25  521 Forest St, Seattle, WA 98101
# 4130  03/24/19 08:25  521 Forest St, Seattle, WA 98101

# %%
# Order ID --- 166981

mar_data[mar_data["Order ID"] == "166981"]
# Out:
#      Order ID                 Product Quantity Ordered Price Each  \
# 5214   166981  AAA Batteries (4-pack)                1       2.99
# 5215   166981  AAA Batteries (4-pack)                1       2.99
#
#           Order Date                 Purchase Address
# 5214  03/31/19 01:40  557 Wilson St, Dallas, TX 75001
# 5215  03/31/19 01:40  557 Wilson St, Dallas, TX 75001

# %%
# Order ID --- 167429

mar_data[mar_data["Order ID"] == "167429"]
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 5684   167429  Lightning Charging Cable                1      14.95
# 5685   167429  Lightning Charging Cable                1      14.95
#
#           Order Date                      Purchase Address
# 5684  03/27/19 05:05  430 Lake St, San Francisco, CA 94016
# 5685  03/27/19 05:05  430 Lake St, San Francisco, CA 94016

# %%
# Order ID --- 167654

mar_data[mar_data["Order ID"] == "167654"]
# Out:
#      Order ID           Product Quantity Ordered Price Each      Order Date  \
# 5922   167654  27in FHD Monitor                1     149.99  03/29/19 15:10
# 5923   167654  27in FHD Monitor                1     149.99  03/29/19 15:10
#
#                     Purchase Address
# 5922  654 5th St, Portland, OR 97035
# 5923  654 5th St, Portland, OR 97035

# %%
# Order ID --- 168724

mar_data[mar_data["Order ID"] == "168724"]
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 7032   168724  Apple Airpods Headphones                1        150
# 7033   168724  Apple Airpods Headphones                1        150
#
#           Order Date                    Purchase Address
# 7032  03/13/19 11:25  552 Park St, Los Angeles, CA 90001
# 7033  03/13/19 11:25  552 Park St, Los Angeles, CA 90001

# %%
# Order ID --- 168777

mar_data[mar_data["Order ID"] == "168777"]
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 7086   168777                    iPhone                1        700
# 7087   168777  Lightning Charging Cable                1      14.95
# 7088   168777  Lightning Charging Cable                1      14.95
#
#           Order Date                      Purchase Address
# 7086  03/07/19 14:55  247 Pine St, San Francisco, CA 94016
# 7087  03/07/19 14:55  247 Pine St, San Francisco, CA 94016
# 7088  03/07/19 14:55  247 Pine St, San Francisco, CA 94016

# %%
# Order ID --- 168888

mar_data[mar_data["Order ID"] == "168888"]
# Out:
#      Order ID                Product Quantity Ordered Price Each  \
# 7202   168888  AA Batteries (4-pack)                1       3.84
# 7203   168888  AA Batteries (4-pack)                1       3.84
#
#           Order Date                    Purchase Address
# 7202  03/18/19 14:26  815 Hill St, Los Angeles, CA 90001
# 7203  03/18/19 14:26  815 Hill St, Los Angeles, CA 90001

# %%
# Order ID --- 169600

mar_data[mar_data["Order ID"] == "169600"]
# Out:
#      Order ID           Product Quantity Ordered Price Each      Order Date  \
# 7949   169600  Wired Headphones                1      11.99  03/10/19 11:12
# 7950   169600  Wired Headphones                1      11.99  03/10/19 11:12
#
#                            Purchase Address
# 7949  839 Cedar St, New York City, NY 10001
# 7950  839 Cedar St, New York City, NY 10001

# %%
# Order ID --- 170109

mar_data[mar_data["Order ID"] == "170109"]
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 8486   170109  Apple Airpods Headphones                1        150
# 8487   170109  Apple Airpods Headphones                1        150
#
#           Order Date                  Purchase Address
# 8486  03/16/19 13:35  462 Meadow St, Seattle, WA 98101
# 8487  03/16/19 13:35  462 Meadow St, Seattle, WA 98101

# %%
# Order ID --- 171322

mar_data[mar_data["Order ID"] == "171322"]
# Out:
#      Order ID       Product Quantity Ordered Price Each      Order Date  \
# 9748   171322  20in Monitor                1     109.99  03/15/19 13:45
# 9749   171322  20in Monitor                1     109.99  03/15/19 13:45
#
#                        Purchase Address
# 9748  357 Meadow St, Portland, ME 04101
# 9749  357 Meadow St, Portland, ME 04101

# %%
# Order ID --- 172155

mar_data[mar_data["Order ID"] == "172155"]
# Out:
#       Order ID               Product Quantity Ordered Price Each  \
# 10612   172155  USB-C Charging Cable                1      11.95
# 10613   172155  USB-C Charging Cable                1      11.95
#
#            Order Date                     Purchase Address
# 10612  03/11/19 23:08  712 1st St, New York City, NY 10001
# 10613  03/11/19 23:08  712 1st St, New York City, NY 10001

# %%
# Order ID --- 173388

mar_data[mar_data["Order ID"] == "173388"]
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 11916   173388  Bose SoundSport Headphones                1      99.99
# 11917   173388  Bose SoundSport Headphones                1      99.99
#
#            Order Date                       Purchase Address
# 11916  03/21/19 15:31  96 Cherry St, San Francisco, CA 94016
# 11917  03/21/19 15:31  96 Cherry St, San Francisco, CA 94016

# %%
# Order ID --- 174691

mar_data[mar_data["Order ID"] == "174691"]
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 13282   174691  Apple Airpods Headphones                1        150
# 13283   174691  Apple Airpods Headphones                1        150
#
#            Order Date                    Purchase Address
# 13282  03/17/19 13:22  672 Highland St, Seattle, WA 98101
# 13283  03/17/19 13:22  672 Highland St, Seattle, WA 98101

# %%
# Order ID --- 174972

mar_data[mar_data["Order ID"] == "174972"]
# Out:
#       Order ID               Product Quantity Ordered Price Each  \
# 13575   174972  USB-C Charging Cable                1      11.95
# 13576   174972  USB-C Charging Cable                1      11.95
#
#            Order Date                      Purchase Address
# 13575  03/26/19 23:02  389 10th St, New York City, NY 10001
# 13576  03/26/19 23:02  389 10th St, New York City, NY 10001

# %%
# Order ID --- 176537

mar_data[mar_data["Order ID"] == "176537"]
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 15203   176537  Apple Airpods Headphones                1        150
# 15204   176537  Apple Airpods Headphones                1        150
#
#            Order Date                Purchase Address
# 15203  03/12/19 07:33  80 Church St, Austin, TX 73301
# 15204  03/12/19 07:33  80 Church St, Austin, TX 73301

# %% [markdown]
# From the duplicates investigations, it can be realised that each duplicated entries had same values. One instance of each duplicated entry will be dropped

# %%
# Drop duplicated entries

mar_data.drop_duplicates(subset=None, keep="first", inplace=True)

# %% [markdown]
# ### April Product Sales

# %%
# Checking the head of the April data

apr_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
# Checking the shape of the data

apr_data.shape
# Out:
# (18383, 6)

# %% [markdown]
# The data has 18383 rows and 6 columns

# %%
# Checking the basic info of the data

apr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18383 entries, 0 to 18382
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          18324 non-null  object
#  1   Product           18324 non-null  object
#  2   Quantity Ordered  18324 non-null  object
#  3   Price Each        18324 non-null  object
#  4   Order Date        18324 non-null  object
#  5   Purchase Address  18324 non-null  object
# dtypes: object(6)
# memory usage: 861.8+ KB

# %% [markdown]
# There are null values in the data. The date is also in bject format.

# %%
# Checking the sum of the null values in the data

apr_data.isnull().sum()
# Out:
# Order ID            59
# Product             59
# Quantity Ordered    59
# Price Each          59
# Order Date          59
# Purchase Address    59
# dtype: int64

# %% [markdown]
# There are 59 instances of null values in the data.

# %%
# Drop null values from the data

apr_data.dropna(how="all", axis=0, inplace=True)

# %%
# Check for duplicates in the data

apr_data.duplicated().any()
# Out:
# True

# %%
# Check the sun of duplicated values in the data

apr_data.duplicated().sum()
# Out:
# 56

# %% [markdown]
# There are 56 instances of duplicates in the data

# %%
# Check for the occurrence of the duplicates

apr_data[apr_data.duplicated()]
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 31       176585  Bose SoundSport Headphones                 1       99.99
# 1149   Order ID                     Product  Quantity Ordered  Price Each
# 1155   Order ID                     Product  Quantity Ordered  Price Each
# 1302     177795    Apple Airpods Headphones                 1         150
# 1684     178158        USB-C Charging Cable                 1       11.95
# 2878   Order ID                     Product  Quantity Ordered  Price Each
# 2893   Order ID                     Product  Quantity Ordered  Price Each
# 3036   Order ID                     Product  Quantity Ordered  Price Each
# 3209   Order ID                     Product  Quantity Ordered  Price Each
# 3618   Order ID                     Product  Quantity Ordered  Price Each
# 3805     180207    Apple Airpods Headphones                 1         150
# 4138   Order ID                     Product  Quantity Ordered  Price Each
# 4196     180576    Lightning Charging Cable                 1       14.95
# 4376     180746      AAA Batteries (4-pack)                 1        2.99
# 4450     180817    Lightning Charging Cable                 1       14.95
# 4645   Order ID                     Product  Quantity Ordered  Price Each
# 4734     181084               Flatscreen TV                 1         300
# 4794   Order ID                     Product  Quantity Ordered  Price Each
# 4906     181246            Wired Headphones                 1       11.99
# 5303   Order ID                     Product  Quantity Ordered  Price Each
# 5773     182077      AAA Batteries (4-pack)                 1        2.99
# 6242     182523    Lightning Charging Cable                 1       14.95
# 6646     182904    Lightning Charging Cable                 1       14.95
# 6939   Order ID                     Product  Quantity Ordered  Price Each
# 7372     183587      AAA Batteries (4-pack)                 1        2.99
# 7497   Order ID                     Product  Quantity Ordered  Price Each
# 8540     184717        USB-C Charging Cable                 1       11.95
# 8635   Order ID                     Product  Quantity Ordered  Price Each
# 9044     185193    Lightning Charging Cable                 1       14.95
# 9189   Order ID                     Product  Quantity Ordered  Price Each
# 9329   Order ID                     Product  Quantity Ordered  Price Each
# 9899     186008  Bose SoundSport Headphones                 1       99.99
# 9973   Order ID                     Product  Quantity Ordered  Price Each
# 10885  Order ID                     Product  Quantity Ordered  Price Each
# 10958  Order ID                     Product  Quantity Ordered  Price Each
# 11272  Order ID                     Product  Quantity Ordered  Price Each
# 11334    187379        USB-C Charging Cable                 1       11.95
# 11619  Order ID                     Product  Quantity Ordered  Price Each
# 11742  Order ID                     Product  Quantity Ordered  Price Each
# 11778  Order ID                     Product  Quantity Ordered  Price Each
# 11874  Order ID                     Product  Quantity Ordered  Price Each
# 12455  Order ID                     Product  Quantity Ordered  Price Each
# 12871    188827        USB-C Charging Cable                 1       11.95
# 13362  Order ID                     Product  Quantity Ordered  Price Each
# 14022  Order ID                     Product  Quantity Ordered  Price Each
# 14202    190099       AA Batteries (4-pack)                 1        3.84
# 14522  Order ID                     Product  Quantity Ordered  Price Each
# 14677    190553    Lightning Charging Cable                 1       14.95
# 14860  Order ID                     Product  Quantity Ordered  Price Each
# 15280  Order ID                     Product  Quantity Ordered  Price Each
# 17164    192939      34in Ultrawide Monitor                 1      379.99
# 17208  Order ID                     Product  Quantity Ordered  Price Each
# 17324  Order ID                     Product  Quantity Ordered  Price Each
# 17339  Order ID                     Product  Quantity Ordered  Price Each
# 17744  Order ID                     Product  Quantity Ordered  Price Each
# 18194    193916                20in Monitor                 1      109.99
#
#            Order Date                         Purchase Address
# 31     04/07/19 11:31        823 Highland St, Boston, MA 02215
# 1149       Order Date                         Purchase Address
# 1155       Order Date                         Purchase Address
# 1302   04/27/19 19:45           740 14th St, Seattle, WA 98101
# 1684   04/28/19 21:13   197 Center St, San Francisco, CA 94016
# 2878       Order Date                         Purchase Address
# 2893       Order Date                         Purchase Address
# 3036       Order Date                         Purchase Address
# 3209       Order Date                         Purchase Address
# 3618       Order Date                         Purchase Address
# 3805   04/13/19 01:46        196 7th St, Los Angeles, CA 90001
# 4138       Order Date                         Purchase Address
# 4196   04/18/19 17:23            431 Park St, Dallas, TX 75001
# 4376   04/30/19 12:05     398 West St, New York City, NY 10001
# 4450   04/13/19 18:33       563 13th St, Los Angeles, CA 90001
# 4645       Order Date                         Purchase Address
# 4734   04/07/19 21:36            1 Walnut St, Boston, MA 02215
# 4794       Order Date                         Purchase Address
# 4906   04/09/19 13:58  342 Hickory St, San Francisco, CA 94016
# 5303       Order Date                         Purchase Address
# 5773   04/13/19 22:08      730 4th St, New York City, NY 10001
# 6242   04/24/19 21:16           990 River St, Boston, MA 02215
# 6646   04/09/19 22:15         410 Wilson St, Atlanta, GA 30301
# 6939       Order Date                         Purchase Address
# 7372   04/15/19 00:21     384 Sunset St, Los Angeles, CA 90001
# 7497       Order Date                         Purchase Address
# 8540   04/04/19 10:17         439 Forest St, Atlanta, GA 30301
# 8635       Order Date                         Purchase Address
# 9044   04/16/19 21:38     714 13th St, San Francisco, CA 94016
# 9189       Order Date                         Purchase Address
# 9329       Order Date                         Purchase Address
# 9899   04/17/19 19:36     432 Park St, New York City, NY 10001
# 9973       Order Date                         Purchase Address
# 10885      Order Date                         Purchase Address
# 10958      Order Date                         Purchase Address
# 11272      Order Date                         Purchase Address
# 11334  04/10/19 19:06       504 10th St, Los Angeles, CA 90001
# 11619      Order Date                         Purchase Address
# 11742      Order Date                         Purchase Address
# 11778      Order Date                         Purchase Address
# 11874      Order Date                         Purchase Address
# 12455      Order Date                         Purchase Address
# 12871  04/17/19 18:17   900 Spruce St, New York City, NY 10001
# 13362      Order Date                         Purchase Address
# 14022      Order Date                         Purchase Address
# 14202  04/18/19 08:07     845 Sunset St, Los Angeles, CA 90001
# 14522      Order Date                         Purchase Address
# 14677  04/10/19 17:38  548 Madison St, New York City, NY 10001
# 14860      Order Date                         Purchase Address
# 15280      Order Date                         Purchase Address
# 17164  04/29/19 21:07          519 Adams St, Seattle, WA 98101
# 17208      Order Date                         Purchase Address
# 17324      Order Date                         Purchase Address
# 17339      Order Date                         Purchase Address
# 17744      Order Date                         Purchase Address
# 18194  04/18/19 12:59          653 Cherry St, Dallas, TX 75001

# %%
# Remove "Order ID" from Order ID column

apr_data = apr_data[apr_data["Order ID"] != "Order ID"]

# %%
# Investigate  the issue of duplicated values

# %%
# Order ID --- 176585

apr_data[apr_data["Order ID"] == "176585"]
# Out:
#    Order ID                     Product Quantity Ordered Price Each  \
# 30   176585  Bose SoundSport Headphones                1      99.99
# 31   176585  Bose SoundSport Headphones                1      99.99
#
#         Order Date                   Purchase Address
# 30  04/07/19 11:31  823 Highland St, Boston, MA 02215
# 31  04/07/19 11:31  823 Highland St, Boston, MA 02215

# %%
# Order ID --- 177795

apr_data[apr_data["Order ID"] == "177795"]
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 1301   177795  Apple Airpods Headphones                1        150
# 1302   177795  Apple Airpods Headphones                1        150
#
#           Order Date                Purchase Address
# 1301  04/27/19 19:45  740 14th St, Seattle, WA 98101
# 1302  04/27/19 19:45  740 14th St, Seattle, WA 98101

# %%
# Order ID --- 178158

apr_data[apr_data["Order ID"] == "178158"]
# Out:
#      Order ID               Product Quantity Ordered Price Each  \
# 1681   178158          Google Phone                1        600
# 1682   178158  USB-C Charging Cable                1      11.95
# 1683   178158      Wired Headphones                1      11.99
# 1684   178158  USB-C Charging Cable                1      11.95
#
#           Order Date                        Purchase Address
# 1681  04/28/19 21:13  197 Center St, San Francisco, CA 94016
# 1682  04/28/19 21:13  197 Center St, San Francisco, CA 94016
# 1683  04/28/19 21:13  197 Center St, San Francisco, CA 94016
# 1684  04/28/19 21:13  197 Center St, San Francisco, CA 94016

# %%
# Order ID --- 180207

apr_data[apr_data["Order ID"] == "180207"]
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 3804   180207  Apple Airpods Headphones                1        150
# 3805   180207  Apple Airpods Headphones                1        150
#
#           Order Date                   Purchase Address
# 3804  04/13/19 01:46  196 7th St, Los Angeles, CA 90001
# 3805  04/13/19 01:46  196 7th St, Los Angeles, CA 90001

# %%
# Order ID --- 182077

apr_data[apr_data["Order ID"] == "182077"]
# Out:
#      Order ID                 Product Quantity Ordered Price Each  \
# 5772   182077  AAA Batteries (4-pack)                1       2.99
# 5773   182077  AAA Batteries (4-pack)                1       2.99
#
#           Order Date                     Purchase Address
# 5772  04/13/19 22:08  730 4th St, New York City, NY 10001
# 5773  04/13/19 22:08  730 4th St, New York City, NY 10001

# %%
# Order ID --- 184717

apr_data[apr_data["Order ID"] == "184717"]
# Out:
#      Order ID               Product Quantity Ordered Price Each  \
# 8539   184717  USB-C Charging Cable                1      11.95
# 8540   184717  USB-C Charging Cable                1      11.95
#
#           Order Date                  Purchase Address
# 8539  04/04/19 10:17  439 Forest St, Atlanta, GA 30301
# 8540  04/04/19 10:17  439 Forest St, Atlanta, GA 30301

# %%
# Order ID --- 190553

apr_data[apr_data["Order ID"] == "190553"]
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 14676   190553  Lightning Charging Cable                1      14.95
# 14677   190553  Lightning Charging Cable                1      14.95
#
#            Order Date                         Purchase Address
# 14676  04/10/19 17:38  548 Madison St, New York City, NY 10001
# 14677  04/10/19 17:38  548 Madison St, New York City, NY 10001

# %%
# Order ID --- 192939

apr_data[apr_data["Order ID"] == "192939"]
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 17163   192939  34in Ultrawide Monitor                1     379.99
# 17164   192939  34in Ultrawide Monitor                1     379.99
#
#            Order Date                 Purchase Address
# 17163  04/29/19 21:07  519 Adams St, Seattle, WA 98101
# 17164  04/29/19 21:07  519 Adams St, Seattle, WA 98101

# %%
# Order ID --- 193916

apr_data[apr_data["Order ID"] == "193916"]
# Out:
#       Order ID       Product Quantity Ordered Price Each      Order Date  \
# 18193   193916  20in Monitor                1     109.99  04/18/19 12:59
# 18194   193916  20in Monitor                1     109.99  04/18/19 12:59
#
#                       Purchase Address
# 18193  653 Cherry St, Dallas, TX 75001
# 18194  653 Cherry St, Dallas, TX 75001

# %% [markdown]
# From the duplicates investigations, it can be realised that each duplicated entries had same values. One instance of each duplicated entry will be dropped

# %%
# Drop duplicated entries from data

apr_data.drop_duplicates(subset=None, keep="first", inplace=True)

# %% [markdown]
# ### May Product Sales

# %%
# Checking sample of the May Product sales

may_data.sample(5, random_state=0)
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 10846   204397      USB-C Charging Cable                1      11.95
# 11863   205375  Lightning Charging Cable                1      14.95
# 8503    202176  Lightning Charging Cable                1      14.95
# 9021    202664     AA Batteries (4-pack)                1       3.84
# 11810   205323  Apple Airpods Headphones                1        150
#
#            Order Date                      Purchase Address
# 10846  05/13/19 18:41          997 8th St, Dallas, TX 75001
# 11863  05/15/19 13:10          72 10th St, Dallas, TX 75001
# 8503   05/17/19 22:04  244 Park St, New York City, NY 10001
# 9021   05/24/19 13:29         27 11th St, Atlanta, GA 30301
# 11810  05/07/19 14:17        250 Maple St, Boston, MA 02215

# %%
# Checking the shape of the data

may_data.shape
# Out:
# (16635, 6)

# %% [markdown]
# The May Product data has 16635 rows and 6 columns

# %%
# Checking the basic info of the data

may_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16635 entries, 0 to 16634
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          16587 non-null  object
#  1   Product           16587 non-null  object
#  2   Quantity Ordered  16587 non-null  object
#  3   Price Each        16587 non-null  object
#  4   Order Date        16587 non-null  object
#  5   Purchase Address  16587 non-null  object
# dtypes: object(6)
# memory usage: 779.9+ KB

# %% [markdown]
# There are null values in the dataset

# %%
# Check the sum of null values

may_data.isnull().sum()
# Out:
# Order ID            48
# Product             48
# Quantity Ordered    48
# Price Each          48
# Order Date          48
# Purchase Address    48
# dtype: int64

# %% [markdown]
# There are 48 instances of 48 null values in the data

# %%
# Drop null values from data

may_data.dropna(how="all", axis=0, inplace=True)

# %%
# Check for duplicates in the data

may_data.duplicated().any()
# Out:
# True

# %%
# Chek for the sum of duplicates

may_data.duplicated().sum()
# Out:
# 46

# %% [markdown]
# There are 46 instances of duplicated entries in the data

# %%
# Investigate the issue of duplicates with 5 samples

may_data[may_data.duplicated()].sample(5, random_state=0)
# Out:
#       Order ID                 Product  Quantity Ordered  Price Each  \
# 8799  Order ID                 Product  Quantity Ordered  Price Each
# 8033    201727  AAA Batteries (4-pack)                 1        2.99
# 9558  Order ID                 Product  Quantity Ordered  Price Each
# 1318  Order ID                 Product  Quantity Ordered  Price Each
# 3948    197845    USB-C Charging Cable                 1       11.95
#
#           Order Date                     Purchase Address
# 8799      Order Date                     Purchase Address
# 8033  05/08/19 17:00  659 2nd St, New York City, NY 10001
# 9558      Order Date                     Purchase Address
# 1318      Order Date                     Purchase Address
# 3948  05/09/19 15:23       95 Willow St, Dallas, TX 75001

# %%
# Drop Order ID from data

may_data = may_data[may_data["Order ID"] != "Order ID"]

# %%
# Re-check duplicated values for removal of "Order ID" from Order ID column

may_data[may_data.duplicated()].sample(5, random_state=0)
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 8514    202186  Bose SoundSport Headphones                1      99.99
# 7906    201606       AA Batteries (4-pack)                1       3.84
# 4660    198514        USB-C Charging Cable                1      11.95
# 11494   205018        USB-C Charging Cable                1      11.95
# 2464    196429      AAA Batteries (4-pack)                1       2.99
#
#            Order Date                      Purchase Address
# 8514   05/16/19 07:09     296 1st St, Los Angeles, CA 90001
# 7906   05/02/19 14:07        309 Main St, Seattle, WA 98101
# 4660   05/13/19 18:56     171 Jackson St, Seattle, WA 98101
# 11494  05/16/19 22:32      859 Lincoln St, Boston, MA 02215
# 2464   05/30/19 17:30  966 11th St, New York City, NY 10001

# %% [markdown]
# #### Investigate issue duplicates with samples

# %%
# Order ID --- 202186

may_data[may_data["Order ID"] == "202186"]
# Out:
#      Order ID                     Product Quantity Ordered Price Each  \
# 8513   202186  Bose SoundSport Headphones                1      99.99
# 8514   202186  Bose SoundSport Headphones                1      99.99
#
#           Order Date                   Purchase Address
# 8513  05/16/19 07:09  296 1st St, Los Angeles, CA 90001
# 8514  05/16/19 07:09  296 1st St, Los Angeles, CA 90001

# %%
# Order ID --- 201606

may_data[may_data["Order ID"] == "201606"]
# Out:
#      Order ID                Product Quantity Ordered Price Each  \
# 7905   201606  AA Batteries (4-pack)                1       3.84
# 7906   201606  AA Batteries (4-pack)                1       3.84
#
#           Order Date                Purchase Address
# 7905  05/02/19 14:07  309 Main St, Seattle, WA 98101
# 7906  05/02/19 14:07  309 Main St, Seattle, WA 98101

# %%
# Order ID --- 198514

may_data[may_data["Order ID"] == "198514"]
# Out:
#      Order ID               Product Quantity Ordered Price Each  \
# 4658   198514          Google Phone                1        600
# 4659   198514  USB-C Charging Cable                1      11.95
# 4660   198514  USB-C Charging Cable                1      11.95
#
#           Order Date                   Purchase Address
# 4658  05/13/19 18:56  171 Jackson St, Seattle, WA 98101
# 4659  05/13/19 18:56  171 Jackson St, Seattle, WA 98101
# 4660  05/13/19 18:56  171 Jackson St, Seattle, WA 98101

# %%
# Order ID --- 205018

may_data[may_data["Order ID"] == "205018"]
# Out:
#       Order ID               Product Quantity Ordered Price Each  \
# 11493   205018  USB-C Charging Cable                1      11.95
# 11494   205018  USB-C Charging Cable                1      11.95
#
#            Order Date                  Purchase Address
# 11493  05/16/19 22:32  859 Lincoln St, Boston, MA 02215
# 11494  05/16/19 22:32  859 Lincoln St, Boston, MA 02215

# %%
# Order ID --- 196429

may_data[may_data["Order ID"] == "196429"]
# Out:
#      Order ID                 Product Quantity Ordered Price Each  \
# 2463   196429  AAA Batteries (4-pack)                1       2.99
# 2464   196429  AAA Batteries (4-pack)                1       2.99
#
#           Order Date                      Purchase Address
# 2463  05/30/19 17:30  966 11th St, New York City, NY 10001
# 2464  05/30/19 17:30  966 11th St, New York City, NY 10001

# %% [markdown]
# From the duplicates investigations, it can be realised that each duplicated entries had same values. One instance of each duplicated entry will be dropped

# %%
# Drop duplicated entries

may_data.drop_duplicates(subset=None, keep="first", inplace=True)

# %% [markdown]
# ### June Product Sales

# %%
# Checking the head of the June product sales data

jun_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   209921        USB-C Charging Cable                1      11.95
# 1   209922          Macbook Pro Laptop                1     1700.0
# 2   209923             ThinkPad Laptop                1     999.99
# 3   209924            27in FHD Monitor                1     149.99
# 4   209925  Bose SoundSport Headphones                1      99.99
#
#        Order Date                       Purchase Address
# 0  06/23/19 19:34      950 Walnut St, Portland, ME 04101
# 1  06/30/19 10:05     80 4th St, San Francisco, CA 94016
# 2  06/24/19 20:18  402 Jackson St, Los Angeles, CA 90001
# 3  06/05/19 10:21         560 10th St, Seattle, WA 98101
# 4  06/25/19 18:58    545 2nd St, San Francisco, CA 94016

# %%
# Check the shape of the data

jun_data.shape
# Out:
# (13622, 6)

# %%
# Check the basic info of data

jun_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13622 entries, 0 to 13621
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          13579 non-null  object
#  1   Product           13579 non-null  object
#  2   Quantity Ordered  13579 non-null  object
#  3   Price Each        13579 non-null  object
#  4   Order Date        13579 non-null  object
#  5   Purchase Address  13579 non-null  object
# dtypes: object(6)
# memory usage: 638.7+ KB

# %% [markdown]
# There are null values in the dataset

# %%
# Check the sum of null values

jun_data.isnull().sum()
# Out:
# Order ID            43
# Product             43
# Quantity Ordered    43
# Price Each          43
# Order Date          43
# Purchase Address    43
# dtype: int64

# %% [markdown]
# There are 43 instances of null values in the data. These values will be removed

# %%
# Drop null values from data

jun_data.dropna(how="all", axis=0, inplace=True)

# %%
# Check for duplicats in the data

jun_data.duplicated().any()
# Out:
# True

# %%
# Check the sum of duplicated entries in the data

jun_data.duplicated().sum()
# Out:
# 41

# %% [markdown]
# There are 41 instances of dupliacted value in the data

# %%
# Check the instance of duplicates with 5 sample

jun_data[jun_data.duplicated()].sample(5, random_state=0)
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 8251   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 10813  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 8918   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1679   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3918   Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#        Purchase Address
# 8251   Purchase Address
# 10813  Purchase Address
# 8918   Purchase Address
# 1679   Purchase Address
# 3918   Purchase Address

# %%
# Remove "Order ID" as a value from the data

jun_data = jun_data[jun_data["Order ID"] != "Order ID"]

# %%
# Re-checking 5 samples of duplicated entries

jun_data[jun_data.duplicated()].sample(5, random_state=0)
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 7651    217210    Apple Airpods Headphones                1        150
# 1080    210950    Apple Airpods Headphones                1        150
# 6528    216126            Wired Headphones                1      11.99
# 12356   221711  Bose SoundSport Headphones                1      99.99
# 9267    218756      AAA Batteries (4-pack)                1       2.99
#
#            Order Date                         Purchase Address
# 7651   06/11/19 15:31            258 10th St, Boston, MA 02215
# 1080   06/22/19 20:00  479 Hickory St, New York City, NY 10001
# 6528   06/29/19 07:53       3 12th St, New York City, NY 10001
# 12356  06/15/19 16:36     139 West St, New York City, NY 10001
# 9267   06/11/19 14:54         362 Hickory St, Boston, MA 02215

# %% [markdown]
# #### Investigating the issue of duplicated entries with the samples above

# %%
# Order ID --- 217210

jun_data[jun_data["Order ID"] == "217210"]
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 7650   217210  Apple Airpods Headphones                1        150
# 7651   217210  Apple Airpods Headphones                1        150
#
#           Order Date               Purchase Address
# 7650  06/11/19 15:31  258 10th St, Boston, MA 02215
# 7651  06/11/19 15:31  258 10th St, Boston, MA 02215

# %%
# Order ID --- 210950

jun_data[jun_data["Order ID"] == "210950"]
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 1079   210950  Apple Airpods Headphones                1        150
# 1080   210950  Apple Airpods Headphones                1        150
#
#           Order Date                         Purchase Address
# 1079  06/22/19 20:00  479 Hickory St, New York City, NY 10001
# 1080  06/22/19 20:00  479 Hickory St, New York City, NY 10001

# %%
# Order ID --- 216126

jun_data[jun_data["Order ID"] == "216126"]
# Out:
#      Order ID           Product Quantity Ordered Price Each      Order Date  \
# 6527   216126  Wired Headphones                1      11.99  06/29/19 07:53
# 6528   216126  Wired Headphones                1      11.99  06/29/19 07:53
#
#                         Purchase Address
# 6527  3 12th St, New York City, NY 10001
# 6528  3 12th St, New York City, NY 10001

# %%
# Order ID --- 221711

jun_data[jun_data["Order ID"] == "221711"]
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 12355   221711  Bose SoundSport Headphones                1      99.99
# 12356   221711  Bose SoundSport Headphones                1      99.99
#
#            Order Date                      Purchase Address
# 12355  06/15/19 16:36  139 West St, New York City, NY 10001
# 12356  06/15/19 16:36  139 West St, New York City, NY 10001

# %%
# Order ID --- 218756

jun_data[jun_data["Order ID"] == "218756"]
# Out:
#      Order ID                 Product Quantity Ordered Price Each  \
# 9266   218756  AAA Batteries (4-pack)                1       2.99
# 9267   218756  AAA Batteries (4-pack)                1       2.99
#
#           Order Date                  Purchase Address
# 9266  06/11/19 14:54  362 Hickory St, Boston, MA 02215
# 9267  06/11/19 14:54  362 Hickory St, Boston, MA 02215

# %% [markdown]
# From the duplicates investigations, it can be realised that each duplicated entries had same values. One instance of each duplicated entry will be dropped

# %%
# Drop duplicated entries from data

jun_data.drop_duplicates(subset=None, keep="first", inplace=True)

# %% [markdown]
# ### July Product Sales

# %%
# check the head of the July Product Sales data

jul_data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   222910  Apple Airpods Headphones                1        150
# 1   222911             Flatscreen TV                1        300
# 2   222912     AA Batteries (4-pack)                1       3.84
# 3   222913     AA Batteries (4-pack)                1       3.84
# 4   222914    AAA Batteries (4-pack)                5       2.99
#
#        Order Date                  Purchase Address
# 0  07/26/19 16:51   389 South St, Atlanta, GA 30301
# 1  07/05/19 08:55     590 4th St, Seattle, WA 98101
# 2  07/29/19 12:41    861 Hill St, Atlanta, GA 30301
# 3  07/28/19 10:15   190 Ridge St, Atlanta, GA 30301
# 4  07/31/19 02:13  824 Forest St, Seattle, WA 98101

# %%
# Check the shape of the data

jul_data.shape
# Out:
# (14371, 6)

# %% [markdown]
# The data has 14371 rows and 6 columns

# %%
# Check the basic info of the data

jul_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14371 entries, 0 to 14370
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          14326 non-null  object
#  1   Product           14326 non-null  object
#  2   Quantity Ordered  14326 non-null  object
#  3   Price Each        14326 non-null  object
#  4   Order Date        14326 non-null  object
#  5   Purchase Address  14326 non-null  object
# dtypes: object(6)
# memory usage: 673.8+ KB

# %% [markdown]
# The data has null values that need to be treated. Certain colums are also not in their correct data types.

# %%
# Check for the sum of null values in the data

jul_data.isnull().sum()
# Out:
# Order ID            45
# Product             45
# Quantity Ordered    45
# Price Each          45
# Order Date          45
# Purchase Address    45
# dtype: int64

# %% [markdown]
# There are 45 instances of null values in the data

# %%
# Remove null values from the data

jul_data.dropna(how="all", inplace=True)

# %%
# Check for duplicates in the data

jul_data.duplicated().any()
# Out:
# True

# %% [markdown]
# There are duplicated values in the data

# %%
# Check for duplicated values using the tail of the data

jul_data[jul_data.duplicated()].tail()
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 11859    234258  Lightning Charging Cable                 1       14.95
# 11989  Order ID                   Product  Quantity Ordered  Price Each
# 12037  Order ID                   Product  Quantity Ordered  Price Each
# 12681  Order ID                   Product  Quantity Ordered  Price Each
# 13908  Order ID                   Product  Quantity Ordered  Price Each
#
#            Order Date                     Purchase Address
# 11859  07/16/19 15:37  341 2nd St, San Francisco, CA 94016
# 11989      Order Date                     Purchase Address
# 12037      Order Date                     Purchase Address
# 12681      Order Date                     Purchase Address
# 13908      Order Date                     Purchase Address

# %%
# Remove Order ID as value from the Order ID column

jul_data = jul_data[jul_data["Order ID"] != "Order ID"]

# %%
# Check sample of duplicated values

jul_data[jul_data.duplicated()].sample(5, random_state=0)
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 3580    226333      AAA Batteries (4-pack)                1       2.99
# 4888    227586  Bose SoundSport Headphones                1      99.99
# 5776    228433  Bose SoundSport Headphones                1      99.99
# 7105    229701            27in FHD Monitor                1     149.99
# 10875   233314    Lightning Charging Cable                1      14.95
#
#            Order Date                       Purchase Address
# 3580   07/05/19 09:33         947 West St, Seattle, WA 98101
# 4888   07/25/19 13:36   416 Sunset St, Los Angeles, CA 90001
# 5776   07/08/19 20:32  481 Maple St, San Francisco, CA 94016
# 7105   07/25/19 10:22    696 Adams St, Los Angeles, CA 90001
# 10875  07/18/19 15:04           237 4th St, Boston, MA 02215

# %% [markdown]
# #### Investigate the issue of duplicated values using the sample

# %%
# Order ID --- 226333

jul_data[jul_data["Order ID"] == "226333"]
# Out:
#      Order ID                 Product Quantity Ordered Price Each  \
# 3579   226333  AAA Batteries (4-pack)                1       2.99
# 3580   226333  AAA Batteries (4-pack)                1       2.99
#
#           Order Date                Purchase Address
# 3579  07/05/19 09:33  947 West St, Seattle, WA 98101
# 3580  07/05/19 09:33  947 West St, Seattle, WA 98101

# %%
# Order ID --- 227586

jul_data[jul_data["Order ID"] == "227586"]
# Out:
#      Order ID                     Product Quantity Ordered Price Each  \
# 4887   227586  Bose SoundSport Headphones                1      99.99
# 4888   227586  Bose SoundSport Headphones                1      99.99
#
#           Order Date                      Purchase Address
# 4887  07/25/19 13:36  416 Sunset St, Los Angeles, CA 90001
# 4888  07/25/19 13:36  416 Sunset St, Los Angeles, CA 90001

# %%
# Order ID --- 228433

jul_data[jul_data["Order ID"] == "228433"]
# Out:
#      Order ID                     Product Quantity Ordered Price Each  \
# 5775   228433  Bose SoundSport Headphones                1      99.99
# 5776   228433  Bose SoundSport Headphones                1      99.99
#
#           Order Date                       Purchase Address
# 5775  07/08/19 20:32  481 Maple St, San Francisco, CA 94016
# 5776  07/08/19 20:32  481 Maple St, San Francisco, CA 94016

# %%
# Order ID --- 229701

jul_data[jul_data["Order ID"] == "229701"]
# Out:
#      Order ID           Product Quantity Ordered Price Each      Order Date  \
# 7104   229701  27in FHD Monitor                1     149.99  07/25/19 10:22
# 7105   229701  27in FHD Monitor                1     149.99  07/25/19 10:22
#
#                          Purchase Address
# 7104  696 Adams St, Los Angeles, CA 90001
# 7105  696 Adams St, Los Angeles, CA 90001

# %%
# Order ID --- 233314

jul_data[jul_data["Order ID"] == "233314"]
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 10874   233314  Lightning Charging Cable                1      14.95
# 10875   233314  Lightning Charging Cable                1      14.95
#
#            Order Date              Purchase Address
# 10874  07/18/19 15:04  237 4th St, Boston, MA 02215
# 10875  07/18/19 15:04  237 4th St, Boston, MA 02215

# %%
# Remove duplicated values from the data

jul_data.drop_duplicates(subset=None, keep="first", inplace=True)

# %% [markdown]
# ### August Product Sales

# %%
# Check the head of the August Product Sales data

aug_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   236670            Wired Headphones                2      11.99
# 1   236671  Bose SoundSport Headphones                1      99.99
# 2   236672                      iPhone                1      700.0
# 3   236673       AA Batteries (4-pack)                2       3.84
# 4   236674       AA Batteries (4-pack)                2       3.84
#
#        Order Date                      Purchase Address
# 0  08/31/19 22:21      359 Spruce St, Seattle, WA 98101
# 1  08/15/19 15:11        492 Ridge St, Dallas, TX 75001
# 2  08/06/19 14:40        149 7th St, Portland, OR 97035
# 3  08/29/19 20:59     631 2nd St, Los Angeles, CA 90001
# 4  08/15/19 19:53  736 14th St, New York City, NY 10001

# %%
# Check the shape of the data

aug_data.shape
# Out:
# (12011, 6)

# %% [markdown]
# The data has 12011 rows and 6 columns

# %%
# Check the basic info of the data

aug_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12011 entries, 0 to 12010
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          11983 non-null  object
#  1   Product           11983 non-null  object
#  2   Quantity Ordered  11983 non-null  object
#  3   Price Each        11983 non-null  object
#  4   Order Date        11983 non-null  object
#  5   Purchase Address  11983 non-null  object
# dtypes: object(6)
# memory usage: 563.1+ KB

# %% [markdown]
# The data has missing values. Also, some of the columns are not in their correct data types

# %%
# Check the sum of null values in the data

aug_data.isnull().sum()
# Out:
# Order ID            28
# Product             28
# Quantity Ordered    28
# Price Each          28
# Order Date          28
# Purchase Address    28
# dtype: int64

# %% [markdown]
# There are 28 instances of missing values in the data. These missing vakues will be dropped from the data

# %%
# Drop missing values form the data

aug_data.dropna(how="all", inplace=True)

# %%
# Check duplicated values in the data

aug_data.duplicated().any()
# Out:
# True

# %% [markdown]
# There are duplicated entries in the data. These entries will be treated after an investigation

# %%
# Check for the instance of duplication using tail of data

aug_data[aug_data.duplicated()].tail()
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 10876    247075    USB-C Charging Cable                 1       11.95
# 11004  Order ID                 Product  Quantity Ordered  Price Each
# 11506    247673    USB-C Charging Cable                 1       11.95
# 11711    247868  34in Ultrawide Monitor                 1      379.99
# 11891    248036    USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address
# 10876  08/10/19 19:18    213 Main St, New York City, NY 10001
# 11004      Order Date                        Purchase Address
# 11506  08/19/19 19:27   600 River St, San Francisco, CA 94016
# 11711  08/19/19 07:39  151 Willow St, New York City, NY 10001
# 11891  08/06/19 19:56  340 Cherry St, San Francisco, CA 94016

# %%
# Remove Order ID as values from the Order ID column

aug_data = aug_data[aug_data["Order ID"] != "Order ID"]

# %%
# Check for instance of duplicated entries using samples

aug_data[aug_data.duplicated()].sample(5, random_state=0)
# Out:
#       Order ID               Product Quantity Ordered Price Each  \
# 925     237560  USB-C Charging Cable                1      11.95
# 7373    243728    Macbook Pro Laptop                1       1700
# 8422    244727      Wired Headphones                1      11.99
# 9855    246092  USB-C Charging Cable                1      11.95
# 10876   247075  USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# 925    08/09/19 00:26  397 Lincoln St, San Francisco, CA 94016
# 7373   08/26/19 12:57       665 14th St, Los Angeles, CA 90001
# 8422   08/29/19 16:00       36 North St, Los Angeles, CA 90001
# 9855   08/03/19 09:47       175 Main St, Los Angeles, CA 90001
# 10876  08/10/19 19:18     213 Main St, New York City, NY 10001

# %% [markdown]
# #### Investigate the issue of duplicated entries using the listed sample

# %%
# Order ID --- 237560

aug_data[aug_data["Order ID"] == "237560"]
# Out:
#     Order ID               Product Quantity Ordered Price Each  \
# 924   237560  USB-C Charging Cable                1      11.95
# 925   237560  USB-C Charging Cable                1      11.95
#
#          Order Date                         Purchase Address
# 924  08/09/19 00:26  397 Lincoln St, San Francisco, CA 94016
# 925  08/09/19 00:26  397 Lincoln St, San Francisco, CA 94016

# %%
# Order ID --- 243728

aug_data[aug_data["Order ID"] == "243728"]
# Out:
#      Order ID             Product Quantity Ordered Price Each      Order Date  \
# 7372   243728  Macbook Pro Laptop                1       1700  08/26/19 12:57
# 7373   243728  Macbook Pro Laptop                1       1700  08/26/19 12:57
#
#                         Purchase Address
# 7372  665 14th St, Los Angeles, CA 90001
# 7373  665 14th St, Los Angeles, CA 90001

# %%
# Order ID --- 244727

aug_data[aug_data["Order ID"] == "244727"]
# Out:
#      Order ID           Product Quantity Ordered Price Each      Order Date  \
# 8421   244727  Wired Headphones                1      11.99  08/29/19 16:00
# 8422   244727  Wired Headphones                1      11.99  08/29/19 16:00
#
#                         Purchase Address
# 8421  36 North St, Los Angeles, CA 90001
# 8422  36 North St, Los Angeles, CA 90001

# %%
# Order ID --- 246092

aug_data[aug_data["Order ID"] == "246092"]
# Out:
#      Order ID               Product Quantity Ordered Price Each  \
# 9854   246092  USB-C Charging Cable                1      11.95
# 9855   246092  USB-C Charging Cable                1      11.95
#
#           Order Date                    Purchase Address
# 9854  08/03/19 09:47  175 Main St, Los Angeles, CA 90001
# 9855  08/03/19 09:47  175 Main St, Los Angeles, CA 90001

# %%
# Order ID --- 247075

aug_data[aug_data["Order ID"] == "247075"]
# Out:
#       Order ID               Product Quantity Ordered Price Each  \
# 10875   247075  USB-C Charging Cable                1      11.95
# 10876   247075  USB-C Charging Cable                1      11.95
#
#            Order Date                      Purchase Address
# 10875  08/10/19 19:18  213 Main St, New York City, NY 10001
# 10876  08/10/19 19:18  213 Main St, New York City, NY 10001

# %% [markdown]
# All the sample investigations show entries that were recorded more than once with same values. The duplicates will be dropped from the data

# %%
# Drop duplicated values from the data

aug_data.drop_duplicates(subset=None, keep="first", inplace=True)

# %% [markdown]
# ### September Product Sales

# %%
# Check the head of the data

sep_data.head()
# Out:
#   Order ID                Product Quantity Ordered Price Each      Order Date  \
# 0   248151  AA Batteries (4-pack)                4       3.84  09/17/19 14:44
# 1   248152   USB-C Charging Cable                2      11.95  09/29/19 10:19
# 2   248153   USB-C Charging Cable                1      11.95  09/16/19 17:48
# 3   248154       27in FHD Monitor                1     149.99  09/27/19 07:52
# 4   248155   USB-C Charging Cable                1      11.95  09/01/19 19:03
#
#                         Purchase Address
# 0    380 North St, Los Angeles, CA 90001
# 1           511 8th St, Austin, TX 73301
# 2  151 Johnson St, Los Angeles, CA 90001
# 3      355 Hickory St, Seattle, WA 98101
# 4          125 5th St, Atlanta, GA 30301

# %%
# Check the shape of the data

sep_data.shape
# Out:
# (11686, 6)

# %% [markdown]
# The data has 11686 rows and 6 columns

# %%
# Check the info of the data

sep_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11686 entries, 0 to 11685
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          11646 non-null  object
#  1   Product           11646 non-null  object
#  2   Quantity Ordered  11646 non-null  object
#  3   Price Each        11646 non-null  object
#  4   Order Date        11646 non-null  object
#  5   Purchase Address  11646 non-null  object
# dtypes: object(6)
# memory usage: 547.9+ KB

# %% [markdown]
# There are null values in the data that will be treated. Also, some of the columnd are not in their correct data types

# %%
# Check for the sum of null values in the data

sep_data.isnull().sum()
# Out:
# Order ID            40
# Product             40
# Quantity Ordered    40
# Price Each          40
# Order Date          40
# Purchase Address    40
# dtype: int64

# %% [markdown]
# There are 40 instances of null values in the data. These null values will be removed from the data

# %%
sep_data.dropna(how="all", inplace=True)

# %%
# Check for duplicated values in the data

sep_data.duplicated().any()
# Out:
# True

# %% [markdown]
# There are duplicated values in the data. These duplicates will be investigated.

# %%
# Check the occurrence of duplicates in the data

sep_data[sep_data.duplicated()].tail()
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 11399  Order ID                   Product  Quantity Ordered  Price Each
# 11468  Order ID                   Product  Quantity Ordered  Price Each
# 11574  Order ID                   Product  Quantity Ordered  Price Each
# 11618    259296  Apple Airpods Headphones                 1         150
# 11621    259297  Lightning Charging Cable                 1       14.95
#
#            Order Date               Purchase Address
# 11399      Order Date               Purchase Address
# 11468      Order Date               Purchase Address
# 11574      Order Date               Purchase Address
# 11618  09/28/19 16:48   894 6th St, Dallas, TX 75001
# 11621  09/15/19 18:54  138 Main St, Boston, MA 02215

# %%
# Remove Order ID as value from the Order ID column

sep_data = sep_data[sep_data["Order ID"] != "Order ID"]

# %%
# Check for duplicated entries with samples

sep_data[sep_data.duplicated()].sample(5, random_state=0)
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 658     248787     AA Batteries (4-pack)                1       3.84
# 6082    253981  Lightning Charging Cable                1      14.95
# 7483    255318        Macbook Pro Laptop                1       1700
# 8390    256196      USB-C Charging Cable                1      11.95
# 11009   258715  Lightning Charging Cable                1      14.95
#
#            Order Date                       Purchase Address
# 658    09/09/19 12:30  705 Adams St, San Francisco, CA 94016
# 6082   09/02/19 22:32        811 Adams St, Atlanta, GA 30301
# 7483   09/26/19 11:58       548 Jackson St, Dallas, TX 75001
# 8390   09/27/19 21:09           253 6th St, Boston, MA 02215
# 11009  09/15/19 16:50        550 10th St, Portland, OR 97035

# %% [markdown]
# #### Investigate the issues of duplicated entries with the listed samples

# %%
# Order ID --- 248787

sep_data[sep_data["Order ID"] == "248787"]
# Out:
#     Order ID                Product Quantity Ordered Price Each  \
# 657   248787  AA Batteries (4-pack)                1       3.84
# 658   248787  AA Batteries (4-pack)                1       3.84
#
#          Order Date                       Purchase Address
# 657  09/09/19 12:30  705 Adams St, San Francisco, CA 94016
# 658  09/09/19 12:30  705 Adams St, San Francisco, CA 94016

# %%
# Order ID --- 253981

sep_data[sep_data["Order ID"] == "253981"]
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 6081   253981  Lightning Charging Cable                1      14.95
# 6082   253981  Lightning Charging Cable                1      14.95
#
#           Order Date                 Purchase Address
# 6081  09/02/19 22:32  811 Adams St, Atlanta, GA 30301
# 6082  09/02/19 22:32  811 Adams St, Atlanta, GA 30301

# %%
# Order ID --- 255318

sep_data[sep_data["Order ID"] == "255318"]
# Out:
#      Order ID             Product Quantity Ordered Price Each      Order Date  \
# 7482   255318  Macbook Pro Laptop                1       1700  09/26/19 11:58
# 7483   255318  Macbook Pro Laptop                1       1700  09/26/19 11:58
#
#                       Purchase Address
# 7482  548 Jackson St, Dallas, TX 75001
# 7483  548 Jackson St, Dallas, TX 75001

# %%
# Order ID --- 256196

sep_data[sep_data["Order ID"] == "256196"]
# Out:
#      Order ID               Product Quantity Ordered Price Each  \
# 8389   256196  USB-C Charging Cable                1      11.95
# 8390   256196  USB-C Charging Cable                1      11.95
#
#           Order Date              Purchase Address
# 8389  09/27/19 21:09  253 6th St, Boston, MA 02215
# 8390  09/27/19 21:09  253 6th St, Boston, MA 02215

# %%
# Order ID --- 258715

sep_data[sep_data["Order ID"] == "258715"]
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 11008   258715  Lightning Charging Cable                1      14.95
# 11009   258715  Lightning Charging Cable                1      14.95
#
#            Order Date                 Purchase Address
# 11008  09/15/19 16:50  550 10th St, Portland, OR 97035
# 11009  09/15/19 16:50  550 10th St, Portland, OR 97035

# %% [markdown]
# From the investigations, the duplicated entries are made of same values entered more twice. An instance each of these values will be dropped from the data

# %%
# Drop duplicates from the data

sep_data.drop_duplicates(subset=None, keep="first", inplace=True)

# %% [markdown]
# ### October Product Sales

# %%
# Check head of October product sales data

oct_data.head()
# Out:
#   Order ID                 Product Quantity Ordered Price Each  \
# 0   259358  34in Ultrawide Monitor                1     379.99
# 1   259359  27in 4K Gaming Monitor                1     389.99
# 2   259360  AAA Batteries (4-pack)                2       2.99
# 3   259361        27in FHD Monitor                1     149.99
# 4   259362        Wired Headphones                1      11.99
#
#        Order Date                           Purchase Address
# 0  10/28/19 10:56            609 Cherry St, Dallas, TX 75001
# 1  10/28/19 17:26          225 5th St, Los Angeles, CA 90001
# 2  10/24/19 17:20       967 12th St, New York City, NY 10001
# 3  10/14/19 22:26  628 Jefferson St, New York City, NY 10001
# 4  10/07/19 16:10         534 14th St, Los Angeles, CA 90001

# %%
# Check the shape of the data

oct_data.shape
# Out:
# (20379, 6)

# %% [markdown]
# The data has 20379 rows and 6 columns

# %%
# Check the basic info of the data

oct_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20379 entries, 0 to 20378
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          20317 non-null  object
#  1   Product           20317 non-null  object
#  2   Quantity Ordered  20317 non-null  object
#  3   Price Each        20317 non-null  object
#  4   Order Date        20317 non-null  object
#  5   Purchase Address  20317 non-null  object
# dtypes: object(6)
# memory usage: 955.4+ KB

# %% [markdown]
# The data has missing values. Certain of the columns are also not in the right data types

# %%
# Check the sum of missing values of each column

oct_data.isna().sum()
# Out:
# Order ID            62
# Product             62
# Quantity Ordered    62
# Price Each          62
# Order Date          62
# Purchase Address    62
# dtype: int64

# %% [markdown]
# The data has 62 instances of missing data. These null values will be dropped fromt the data

# %%
# Remove null values from the data

oct_data.dropna(how="all", inplace=True)

# %%
# Check for duplicates in the datat

oct_data.duplicated().any()
# Out:
# True

# %% [markdown]
# There are duplicated entries in the data. These entries will be traeted based on an investigation.

# %%
# Check for the instances of duplicates using the tail of the data

oct_data[oct_data.duplicated()].tail()
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 18617  Order ID                   Product  Quantity Ordered  Price Each
# 18888  Order ID                   Product  Quantity Ordered  Price Each
# 19240    277701  Lightning Charging Cable                 1       14.95
# 19609    278062          Wired Headphones                 1       11.99
# 20303  Order ID                   Product  Quantity Ordered  Price Each
#
#            Order Date                        Purchase Address
# 18617      Order Date                        Purchase Address
# 18888      Order Date                        Purchase Address
# 19240  10/29/19 16:21    386 10th St, San Francisco, CA 94016
# 19609  10/02/19 21:39  769 Walnut St, San Francisco, CA 94016
# 20303      Order Date                        Purchase Address

# %%
# Remove Order ID as value from Order ID column

oct_data = oct_data[oct_data["Order ID"] != "Order ID"]

# %%
# Check for duplicates using samples of 5

oct_data[oct_data.duplicated()].sample(5, random_state=0)
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 7248    266280      USB-C Charging Cable                1      11.95
# 13948   272665          Wired Headphones                1      11.99
# 15527   274175  Lightning Charging Cable                1      14.95
# 11447   270283          Wired Headphones                1      11.99
# 2338    261586    AAA Batteries (4-pack)                1       2.99
#
#            Order Date                        Purchase Address
# 7248   10/02/19 11:11       53 Dogwood St, Portland, OR 97035
# 13948  10/29/19 19:52        138 Madison St, Dallas, TX 75001
# 15527  10/28/19 07:26           32 River St, Boston, MA 02215
# 11447  10/02/19 14:51  327 Meadow St, San Francisco, CA 94016
# 2338   10/11/19 20:03      703 Main St, Los Angeles, CA 90001

# %% [markdown]
# #### Investigate the issue of duplicated entries using the samples listed above

# %%
# Order ID --- 266280

oct_data[oct_data["Order ID"] == "266280"]
# Out:
#      Order ID               Product Quantity Ordered Price Each  \
# 7247   266280  USB-C Charging Cable                1      11.95
# 7248   266280  USB-C Charging Cable                1      11.95
#
#           Order Date                   Purchase Address
# 7247  10/02/19 11:11  53 Dogwood St, Portland, OR 97035
# 7248  10/02/19 11:11  53 Dogwood St, Portland, OR 97035

# %%
# Order ID --- 272665

oct_data[oct_data["Order ID"] == "272665"]
# Out:
#       Order ID           Product Quantity Ordered Price Each      Order Date  \
# 13947   272665  Wired Headphones                1      11.99  10/29/19 19:52
# 13948   272665  Wired Headphones                1      11.99  10/29/19 19:52
#
#                        Purchase Address
# 13947  138 Madison St, Dallas, TX 75001
# 13948  138 Madison St, Dallas, TX 75001

# %%
# Order ID --- 274175

oct_data[oct_data["Order ID"] == "274175"]
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 15526   274175  Lightning Charging Cable                1      14.95
# 15527   274175  Lightning Charging Cable                1      14.95
#
#            Order Date               Purchase Address
# 15526  10/28/19 07:26  32 River St, Boston, MA 02215
# 15527  10/28/19 07:26  32 River St, Boston, MA 02215

# %%
# Order ID --- 270283

oct_data[oct_data["Order ID"] == "270283"]
# Out:
#       Order ID           Product Quantity Ordered Price Each      Order Date  \
# 11446   270283  Wired Headphones                1      11.99  10/02/19 14:51
# 11447   270283  Wired Headphones                1      11.99  10/02/19 14:51
#
#                              Purchase Address
# 11446  327 Meadow St, San Francisco, CA 94016
# 11447  327 Meadow St, San Francisco, CA 94016

# %%
# Order ID --- 261586

oct_data[oct_data["Order ID"] == "261586"]
# Out:
#      Order ID                 Product Quantity Ordered Price Each  \
# 2337   261586  AAA Batteries (4-pack)                1       2.99
# 2338   261586  AAA Batteries (4-pack)                1       2.99
#
#           Order Date                    Purchase Address
# 2337  10/11/19 20:03  703 Main St, Los Angeles, CA 90001
# 2338  10/11/19 20:03  703 Main St, Los Angeles, CA 90001

# %% [markdown]
# From the investigations, these entries were entered with same values twice. An instance each of the entries will dropped from the data

# %%
# Drop duplicated entries from the data

oct_data.drop_duplicates(subset=None, keep="first", inplace=True)

# %% [markdown]
# ### November Product Sales

# %%
# Check the head of the Novermber Product Salesdata

nov_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   278797            Wired Headphones                1      11.99
# 1   278798        USB-C Charging Cable                2      11.95
# 2   278799    Apple Airpods Headphones                1      150.0
# 3   278800            27in FHD Monitor                1     149.99
# 4   278801  Bose SoundSport Headphones                1      99.99
#
#        Order Date                      Purchase Address
# 0  11/21/19 09:54   46 Park St, New York City, NY 10001
# 1  11/17/19 10:03      962 Hickory St, Austin, TX 73301
# 2  11/19/19 14:56  464 Cherry St, Los Angeles, CA 90001
# 3  11/25/19 22:24        649 10th St, Seattle, WA 98101
# 4  11/09/19 13:56         522 Hill St, Boston, MA 02215

# %%
# Check the shape of the data

nov_data.shape
# Out:
# (17661, 6)

# %% [markdown]
# The data has 17661 rows and 6 columns

# %%
# Check the basic info of the dataset

nov_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17661 entries, 0 to 17660
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          17616 non-null  object
#  1   Product           17616 non-null  object
#  2   Quantity Ordered  17616 non-null  object
#  3   Price Each        17616 non-null  object
#  4   Order Date        17616 non-null  object
#  5   Purchase Address  17616 non-null  object
# dtypes: object(6)
# memory usage: 828.0+ KB

# %% [markdown]
# The dataset has some missing values. There are columns which are not in the correct data types.

# %%
# Check the sum of missing values

nov_data.isna().sum()
# Out:
# Order ID            45
# Product             45
# Quantity Ordered    45
# Price Each          45
# Order Date          45
# Purchase Address    45
# dtype: int64

# %% [markdown]
# There are 45 instances of missing values in the data. These missing values will be dropped from the data

# %%
# Drop missing values from the data

nov_data.dropna(how="all", inplace=True)

# %%
# Check for duplicated values in the data

nov_data.duplicated().any()
# Out:
# True

# %% [raw]
# There are duplicated entries in the data. These entries will be investigated and treated.

# %%
# Check for the occurrence of duplicated entries

nov_data[nov_data.duplicated()].tail()
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 16014  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 16654  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 17047  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 17147  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 17259  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#        Purchase Address
# 16014  Purchase Address
# 16654  Purchase Address
# 17047  Purchase Address
# 17147  Purchase Address
# 17259  Purchase Address

# %%
# Remove Order ID as value from the Order ID column

nov_data = nov_data[nov_data["Order ID"] != "Order ID"]

# %%
# Check the occurrence of duplicates using samples

nov_data[nov_data.duplicated()].sample(5, random_state=0)
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 985     279736  Bose SoundSport Headphones                1      99.99
# 10281   288620        USB-C Charging Cable                1      11.95
# 13748   291932               Flatscreen TV                1        300
# 5631    284179      AAA Batteries (4-pack)                1       2.99
# 4944    283528            Wired Headphones                1      11.99
#
#            Order Date                        Purchase Address
# 985    11/05/19 17:02          770 North St, Dallas, TX 75001
# 10281  11/29/19 12:54  637 Willow St, San Francisco, CA 94016
# 13748  11/11/19 17:16  340 Center St, San Francisco, CA 94016
# 5631   11/20/19 20:48           614 Hill St, Dallas, TX 75001
# 4944   11/13/19 10:05   486 Johnson St, Los Angeles, CA 90001

# %% [markdown]
# #### Investigate the issue of duplicates using the listed samples

# %%
# Order ID --- 279736

nov_data[nov_data["Order ID"] == "279736"]
# Out:
#     Order ID                     Product Quantity Ordered Price Each  \
# 984   279736  Bose SoundSport Headphones                1      99.99
# 985   279736  Bose SoundSport Headphones                1      99.99
#
#          Order Date                Purchase Address
# 984  11/05/19 17:02  770 North St, Dallas, TX 75001
# 985  11/05/19 17:02  770 North St, Dallas, TX 75001

# %%
# Order ID --- 288620

nov_data[nov_data["Order ID"] == "288620"]
# Out:
#       Order ID               Product Quantity Ordered Price Each  \
# 10280   288620  USB-C Charging Cable                1      11.95
# 10281   288620  USB-C Charging Cable                1      11.95
#
#            Order Date                        Purchase Address
# 10280  11/29/19 12:54  637 Willow St, San Francisco, CA 94016
# 10281  11/29/19 12:54  637 Willow St, San Francisco, CA 94016

# %%
# Order ID --- 291932

nov_data[nov_data["Order ID"] == "291932"]
# Out:
#       Order ID        Product Quantity Ordered Price Each      Order Date  \
# 13747   291932  Flatscreen TV                1        300  11/11/19 17:16
# 13748   291932  Flatscreen TV                1        300  11/11/19 17:16
#
#                              Purchase Address
# 13747  340 Center St, San Francisco, CA 94016
# 13748  340 Center St, San Francisco, CA 94016

# %%
# Order ID --- 284179

nov_data[nov_data["Order ID"] == "284179"]
# Out:
#      Order ID                 Product Quantity Ordered Price Each  \
# 5630   284179  AAA Batteries (4-pack)                1       2.99
# 5631   284179  AAA Batteries (4-pack)                1       2.99
#
#           Order Date               Purchase Address
# 5630  11/20/19 20:48  614 Hill St, Dallas, TX 75001
# 5631  11/20/19 20:48  614 Hill St, Dallas, TX 75001

# %%
# Order ID --- 283528

nov_data[nov_data["Order ID"] == "283528"]
# Out:
#      Order ID           Product Quantity Ordered Price Each      Order Date  \
# 4943   283528  Wired Headphones                1      11.99  11/13/19 10:05
# 4944   283528  Wired Headphones                1      11.99  11/13/19 10:05
#
#                            Purchase Address
# 4943  486 Johnson St, Los Angeles, CA 90001
# 4944  486 Johnson St, Los Angeles, CA 90001

# %%
# Remove duplicated entries from dataset

nov_data.drop_duplicates(subset=None, keep="first", inplace=True)

# %% [markdown]
# ### December Product Sales

# %%
# Check head of December Product Sales data

dec_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %%
# Check the shape of the data

dec_data.shape
# Out:
# (25117, 6)

# %% [markdown]
# The data has 25117 rows and 6 columns

# %%
# Check the basic info of the data

dec_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25117 entries, 0 to 25116
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          25037 non-null  object
#  1   Product           25037 non-null  object
#  2   Quantity Ordered  25037 non-null  object
#  3   Price Each        25037 non-null  object
#  4   Order Date        25037 non-null  object
#  5   Purchase Address  25037 non-null  object
# dtypes: object(6)
# memory usage: 1.1+ MB

# %% [markdown]
# The data has missing values. Also, there are columns which are not in thr correct datatypes.

# %%
# Check the sum of missing values in the data

dec_data.isna().sum()
# Out:
# Order ID            80
# Product             80
# Quantity Ordered    80
# Price Each          80
# Order Date          80
# Purchase Address    80
# dtype: int64

# %% [markdown]
# There are 80 instances of missing data in the data. These data will be dropped from the data.

# %%
# Drop missing values from the data

dec_data.dropna(how="all", inplace=True)

# %%
# Check for duplicates

dec_data.duplicated().sum()
# Out:
# 87

# %% [markdown]
# There are 87 duplicated entries in the data. These entries will be treated after an investigation.

# %%
# Check for the occurrence of duplicated values

dec_data[dec_data.duplicated()].tail()
# Out:
#        Order ID                Product  Quantity Ordered  Price Each  \
# 23337  Order ID                Product  Quantity Ordered  Price Each
# 23352    317971  AA Batteries (4-pack)                 1        3.84
# 23748  Order ID                Product  Quantity Ordered  Price Each
# 24192  Order ID                Product  Quantity Ordered  Price Each
# 24222  Order ID                Product  Quantity Ordered  Price Each
#
#            Order Date                          Purchase Address
# 23337      Order Date                          Purchase Address
# 23352  12/17/19 18:39  250 Chestnut St, San Francisco, CA 94016
# 23748      Order Date                          Purchase Address
# 24192      Order Date                          Purchase Address
# 24222      Order Date                          Purchase Address

# %%
# Remove Order ID as value from the Order ID column

dec_data = dec_data[dec_data["Order ID"] != "Order ID"]

# %%
# Check the issue of duplicated values with random samples

dec_data[dec_data.duplicated()].sample(5, random_state=0)
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 11342   306485  Lightning Charging Cable                1      14.95
# 11158   306308             Flatscreen TV                1        300
# 12845   307923  Lightning Charging Cable                1      14.95
# 3377    298883          Wired Headphones                1      11.99
# 6411    301780     AA Batteries (4-pack)                1       3.84
#
#            Order Date                       Purchase Address
# 11342  12/01/19 21:57    337 9th St, San Francisco, CA 94016
# 11158  12/13/19 18:00         960 Hill St, Seattle, WA 98101
# 12845  12/07/19 07:56     526 13th St, Los Angeles, CA 90001
# 3377   12/28/19 18:07   516 Willow St, Los Angeles, CA 90001
# 6411   12/09/19 00:54  985 South St, San Francisco, CA 94016

# %% [markdown]
# #### Investigate duplicated entries with listed samples

# %%
# Order ID --- 306485

dec_data[dec_data["Order ID"] == "306485"]
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 11341   306485  Lightning Charging Cable                1      14.95
# 11342   306485  Lightning Charging Cable                1      14.95
#
#            Order Date                     Purchase Address
# 11341  12/01/19 21:57  337 9th St, San Francisco, CA 94016
# 11342  12/01/19 21:57  337 9th St, San Francisco, CA 94016

# %%
# Order ID --- 306308

dec_data[dec_data["Order ID"] == "306308"]
# Out:
#       Order ID        Product Quantity Ordered Price Each      Order Date  \
# 11157   306308  Flatscreen TV                1        300  12/13/19 18:00
# 11158   306308  Flatscreen TV                1        300  12/13/19 18:00
#
#                      Purchase Address
# 11157  960 Hill St, Seattle, WA 98101
# 11158  960 Hill St, Seattle, WA 98101

# %%
# Order ID --- 307923

dec_data[dec_data["Order ID"] == "307923"]
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 12844   307923  Lightning Charging Cable                1      14.95
# 12845   307923  Lightning Charging Cable                1      14.95
#
#            Order Date                    Purchase Address
# 12844  12/07/19 07:56  526 13th St, Los Angeles, CA 90001
# 12845  12/07/19 07:56  526 13th St, Los Angeles, CA 90001

# %%
# Order ID --- 298883

dec_data[dec_data["Order ID"] == "298883"]
# Out:
#      Order ID           Product Quantity Ordered Price Each      Order Date  \
# 3376   298883  Wired Headphones                1      11.99  12/28/19 18:07
# 3377   298883  Wired Headphones                1      11.99  12/28/19 18:07
#
#                           Purchase Address
# 3376  516 Willow St, Los Angeles, CA 90001
# 3377  516 Willow St, Los Angeles, CA 90001

# %%
# Order ID --- 301780

dec_data[dec_data["Order ID"] == "301780"]
# Out:
#      Order ID                Product Quantity Ordered Price Each  \
# 6410   301780  AA Batteries (4-pack)                1       3.84
# 6411   301780  AA Batteries (4-pack)                1       3.84
#
#           Order Date                       Purchase Address
# 6410  12/09/19 00:54  985 South St, San Francisco, CA 94016
# 6411  12/09/19 00:54  985 South St, San Francisco, CA 94016

# %% [markdown]
# All the sample investigations show entries that were recorded more than once with same values. The duplicates will be dropped from the data

# %%
# Drop duplicated values from the data

dec_data.drop_duplicates(subset=None, keep="first", inplace=True)

# %% [markdown]
# ## Merge all monthly product sales data to form a single data

# %%
product_sales = pd.concat([jan_data, feb_data, mar_data, apr_data, may_data, jun_data, jul_data, aug_data, sep_data,
                         oct_data])
product_sales = product_sales.reset_index(drop=True)

# %%
product_sales = pd.concat([product_sales, nov_data, dec_data])
product_sales = product_sales.reset_index(drop=True)

# %%
# Check samples of the product sales data

product_sales.sample(10, random_state=5)
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 146015   281533               Flatscreen TV                1        300
# 45928    185358       AA Batteries (4-pack)                1       3.84
# 118524   255083    Lightning Charging Cable                1      14.95
# 163239   298055      AAA Batteries (4-pack)                1       2.99
# 101135   238362                      iPhone                1        700
# 97007    234376    Apple Airpods Headphones                1        150
# 57006    195967      AAA Batteries (4-pack)                1       2.99
# 920      142118  Bose SoundSport Headphones                1      99.99
# 183769   317816               Flatscreen TV                1        300
# 156042   291154    Lightning Charging Cable                1      14.95
#
#             Order Date                        Purchase Address
# 146015  11/24/19 13:02       489 Jackson St, Seattle, WA 98101
# 45928   04/23/19 12:37           778 Hill St, Dallas, TX 75001
# 118524  09/19/19 18:42  198 Walnut St, New York City, NY 10001
# 163239  12/26/19 12:08        796 Jackson St, Austin, TX 73301
# 101135  08/18/19 13:13         459 Wilson St, Austin, TX 73301
# 97007   07/18/19 13:48         758 Church St, Dallas, TX 75001
# 57006   05/23/19 17:49           695 7th St, Atlanta, GA 30301
# 920     01/12/19 15:34          818 West St, Seattle, WA 98101
# 183769  12/06/19 15:30  132 Church St, New York City, NY 10001
# 156042  11/16/19 08:48  581 Wilson St, San Francisco, CA 94016

# %%
# Check the shape of the data

product_sales.shape
# Out:
# (185686, 6)

# %% [markdown]
# Our new data has 185686 rows and 6 columns

# %%
# Check the basic info of the data

product_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185686 entries, 0 to 185685
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185686 non-null  object
#  1   Product           185686 non-null  object
#  2   Quantity Ordered  185686 non-null  object
#  3   Price Each        185686 non-null  object
#  4   Order Date        185686 non-null  object
#  5   Purchase Address  185686 non-null  object
# dtypes: object(6)
# memory usage: 8.5+ MB

# %% [markdown]
# There are no null values. Some columns are not in the right datatypes

# %%
# Check for duplicates in the data

product_sales.duplicated().any()
# Out:
# False

# %% [markdown]
# There are no duplicates in the new dataset

# %% [markdown]
# ### Save new data to a csv file
#
# Since our new data is free from error and duplicates, we save it to a new csv file for easing loading.

# %%
product_sales.to_csv("product_sales.csv", index=False)
